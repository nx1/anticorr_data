# %%
from glob import glob
import numpy as np
import matplotlib.pyplot as plt

import pandas as pd
from astropy.table import Table
import astropy.units as u
from astropy.coordinates import SkyCoord
from astropy.table import vstack, hstack, join, unique
from astroquery.simbad import Simbad

# %%
import matplotlib
matplotlib.rcParams['mathtext.fontset'] = 'stix'
matplotlib.rcParams['font.family'] = 'STIXGeneral'

# %%
# Fix glob square bracket issue
to_replace = {'[':'[[]',
              ']':'[]]'}

# %%
source_names_dict = {'ESO_243-49_HLX-1'             : 'ESO243-49',
                     'NAME_Holmberg_IX_X-1'         : 'Ho-IX',
                     'Holmberg_II_X-1'              : 'Ho_II',
                     'M31_ULX-1'                    : 'M31_ULX-1',
                     '[LM2005]_NGC_598_ULX1'        : 'M33',         # AKA M33 X-8
                     'RX_J133001+47137'             : 'M51',         # M51 ULX-7
                     '[LM2005]_NGC_3031_ULX1'       : 'M81',         # AKA M81
                     'M82_X-2'                      : 'M82',
                     '[LM2005]_NGC_1042_ULX1'       : 'NGC1042',
                     'NAME_NGC_1313_X-1'            : 'NGC1313',
                     'NAME_NGC_1313_X-2'            : 'NGC1313',
                     '[LM2005]_NGC_247_ULX1'        : 'NGC247',
                     '[LB2005]_NGC_253_X20'         : 'NGC253',       # NGC 253 ULX1
                     'NAME_NGC_300_ULX1'            : 'NGC300',
                     '[LM2005]_NGC_4395_ULX1'       : 'NGC4395',
                     '[LM2005]_NGC_5204_ULX1'       : 'NGC5204',
                     '[LM2005]_NGC_5408_ULX1'       : 'NGC5408',
                     '[SRW2006b]_NGC_55_ULX'        : 'NGC55',
                     '[SST2011]_J141939.39+564137.8': 'NGC5585',       # NGC 5585 ULX (overlapping sources)
                     'NAME_NGC_5907_ULX'            : 'NGC5907',
                     '[LB2005]_NGC_6946_ULX1'       : 'NGC6946',
                     '3XMM_J213631.9-543357'        : 'NGC7090',       # NGC 7090
                     'NAME_NGC_7793_P13'            : 'NGC7793',
                     'NAME_NGC_925_ULX-1'           : 'NGC925',
                     'NAME_NGC_925_ULX-2'           : 'NGC925',
                     'SMC_X-3'                      : 'SMC_X-3',
                     'SS433'                        : 'SS433',
                     'SWIFT_J0243.6+6124'           : 'Swift_J0243.6+6124',
                     'NAME_UGC_6456_ULX'            : 'UGC6456',
                     'NOVA_Cyg_1989'                : 'V404Cyg',       # v404 Cygni
                     '[LB2005]_NGC_5236_ULX1'       : 'M83',           # Outer ULX M83
                     'NAME_M83_ULX-1'               : 'M83',           # Inner ULX M83
                     'NAME_NGC_1365-X1'             : 'NGC1365',       # 1365 X-1
                     '[SK2009]_X2'                  : 'NGC1365',       # 1365 X-2
                     'NAME_IC_10_X-1'               : 'IC10',
                     '[WMR2006]_NGC4945_XMM1'       : 'NGC4945',
                     '[LB2005]_NGC_3031_X6'         : 'M81',
                     '[LM2005]_NGC_4559_ULX1'       : 'NGC4559'}           #aka M81

# %%
# Associate Source files with nearsest SIMBAD ID

src_region_dict = {}

s = Simbad
for simbad_name, local_name in source_names_dict.items():
    
    min_sep_file = ''
    min_sep = 9999*u.deg
    
    tab = s.query_object(simbad_name)
    sc1 = SkyCoord(tab['RA'][0], tab['DEC'][0], unit=(u.hourangle, u.deg))
    
    
    src_reg_files = glob(f'../download_scripts/{local_name}/*src*.reg*')
    for r in src_reg_files:
        with open(r, 'r') as f:
            lines = f.readlines()
    
        reg_dict = {}
        for l in lines:
            if 'circle' in l:
                reg = l.replace('\n','')
                ra, dec, radius = reg.replace('circle(','').replace(')','').split(',')
                reg_dict['path'] = r
                reg_dict['region'] = reg
                reg_dict['ra'] = ra
                reg_dict['dec'] = dec
                reg_dict['radius'] = radius
                sc2 = SkyCoord(ra, dec,
                              unit=(u.hourangle, u.deg),
                              frame='fk5')
                
        sep = sc1.separation(sc2)
        if sep < min_sep:
            min_sep = sep
            min_sep_file = r
        #print(f'{simbad_name:<30} {r} Seperation = {sep}')
    
    print(f'{simbad_name:<30} min separation={min_sep_file:<50} ({min_sep:.5f}) {sc1.ra.deg:>.4f} {sc1.dec.deg:>.4f} {sc2.ra.deg:>.4f} {sc2.dec.deg:>.4f}')
    
    src_region_dict[simbad_name] = min_sep_file

assert len(src_region_dict) == len(np.unique(src_region_dict.items())[0]) # Make sure no duplicate src regions
# Out:
# ESO_243-49_HLX-1               min separation=../download_scripts/ESO243-49/src.reg              (0.00028 deg) 17.6179 -46.0729 17.6175 -46.0728
# NAME_Holmberg_IX_X-1           min separation=../download_scripts/Ho-IX/src.reg                  (0.00008 deg) 149.4720 69.0634 149.4718 69.0634
# Holmberg_II_X-1                min separation=../download_scripts/Ho_II/src.reg                  (0.00012 deg) 124.8708 70.7054 124.8707 70.7053
# M31_ULX-1                      min separation=../download_scripts/M31_ULX-1/src.reg              (0.00041 deg) 10.7215 41.2397 10.7217 41.2393
# [LM2005]_NGC_598_ULX1          min separation=../download_scripts/M33/src.reg                    (0.00065 deg) 23.4621 30.6602 23.4618 30.6596
# RX_J133001+47137               min separation=../download_scripts/M51/ULX7_src.reg               (0.00004 deg) 202.5042 47.2289 202.5042 47.2289
# [LM2005]_NGC_3031_ULX1         min separation=../download_scripts/M81/X6_src.reg                 (0.06904 deg) 148.8873 69.0093 148.7903 69.0690
# M82_X-2                        min separation=../download_scripts/M82/src.reg                    (0.00106 deg) 148.9627 69.6793 148.9596 69.6794
# [LM2005]_NGC_1042_ULX1         min separation=../download_scripts/NGC1042/src.reg                (0.00039 deg) 40.1067 -8.4080 40.1067 -8.4084
# NAME_NGC_1313_X-1              min separation=../download_scripts/NGC1313/X-1_src.reg            (0.00041 deg) 49.5833 -66.4864 49.5918 -66.6011
# NAME_NGC_1313_X-2              min separation=../download_scripts/NGC1313/X-2_src.reg            (0.00014 deg) 49.5917 -66.6012 49.5918 -66.6011
# [LM2005]_NGC_247_ULX1          min separation=../download_scripts/NGC247/src.reg                 (0.00133 deg) 11.7667 -20.7960 11.7654 -20.7954
# [LB2005]_NGC_253_X20           min separation=../download_scripts/NGC253/ULX3_src.reg            (0.16247 deg) 12.0833 -25.1694 11.9279 -25.2508
# NAME_NGC_300_ULX1              min separation=../download_scripts/NGC300/src.reg                 (0.00006 deg) 13.7702 -37.6955 13.7702 -37.6954
# [LM2005]_NGC_4395_ULX1         min separation=../download_scripts/NGC4395/src.reg                (0.00072 deg) 186.5064 33.5252 186.5055 33.5253
# [LM2005]_NGC_5204_ULX1         min separation=../download_scripts/NGC5204/src.reg                (0.00049 deg) 202.4109 58.4182 202.4100 58.4183
# [LM2005]_NGC_5408_ULX1         min separation=../download_scripts/NGC5408/src.reg                (0.00068 deg) 210.8318 -41.3830 210.8309 -41.3829
# [SRW2006b]_NGC_55_ULX          min separation=../download_scripts/NGC55/src.reg                  (0.00051 deg) 3.8704 -39.2219 3.8697 -39.2218
# [SST2011]_J141939.39+564137.8  min separation=                                                   (9999.00000 deg) 214.9141 56.6938 3.8697 -39.2218
# NAME_NGC_5907_ULX              min separation=../download_scripts/NGC5907/src.reg                (0.00011 deg) 228.9942 56.3028 228.9940 56.3027
# [LB2005]_NGC_6946_ULX1         min separation=../download_scripts/NGC6946/src.reg                (0.03955 deg) 308.7505 60.1524 308.7524 60.1919
# 3XMM_J213631.9-543357          min separation=../download_scripts/NGC7090/ULX3_src.reg           (0.03278 deg) 324.1331 -54.5659 324.0933 -54.5426
# NAME_NGC_7793_P13              min separation=../download_scripts/NGC7793/src.reg                (0.00000 deg) 359.4621 -32.6241 359.4621 -32.6241
# NAME_NGC_925_ULX-1             min separation=../download_scripts/NGC925/ULX1_src.reg            (0.00029 deg) 36.8647 33.5786 36.8341 33.5702
# NAME_NGC_925_ULX-2             min separation=../download_scripts/NGC925/ULX2_src.reg            (0.00044 deg) 36.8397 33.5836 36.8341 33.5702
# SMC_X-3                        min separation=../download_scripts/SMC_X-3/src.reg                (0.00000 deg) 13.0234 -72.4345 13.0234 -72.4345
# SS433                          min separation=../download_scripts/SS433/src.reg                  (0.00028 deg) 287.9565 4.9827 287.9568 4.9827
# SWIFT_J0243.6+6124             min separation=../download_scripts/Swift_J0243.6+6124/src.reg     (0.00018 deg) 40.9184 61.4344 40.9183 61.4345
# NAME_UGC_6456_ULX              min separation=../download_scripts/UGC6456/src.reg                (0.00040 deg) 172.0125 78.9982 172.0110 78.9984
# NOVA_Cyg_1989                  min separation=../download_scripts/V404Cyg/src.reg                (0.00001 deg) 306.0159 33.8672 306.0159 33.8672
# [LB2005]_NGC_5236_ULX1         min separation=../download_scripts/M83/ulx2_src.reg               (0.00140 deg) 204.3338 -29.8966 204.3325 -29.8973
# NAME_M83_ULX-1                 min separation=../download_scripts/M83/ulx1_src.reg               (0.00020 deg) 204.2714 -29.8686 204.3325 -29.8973
# NAME_NGC_1365-X1               min separation=../download_scripts/NGC1365/X1_src.reg             (0.00067 deg) 53.3942 -36.1597 53.4244 -36.1254
# [SK2009]_X2                    min separation=../download_scripts/NGC1365/X2_src.reg             (0.00000 deg) 53.4244 -36.1254 53.4244 -36.1254
# NAME_IC_10_X-1                 min separation=../download_scripts/IC10/src.reg                   (0.00043 deg) 5.1212 59.2811 5.1204 59.2810
# [WMR2006]_NGC4945_XMM1         min separation=../download_scripts/NGC4945/X1_src.reg             (0.03636 deg) 196.3870 -49.4595 196.3459 -49.4841
# [LB2005]_NGC_3031_X6           min separation=../download_scripts/M81/X6_src.reg                 (0.00027 deg) 148.7907 69.0688 148.7903 69.0690
# [LM2005]_NGC_4559_ULX1         min separation=../download_scripts/NGC4559/src.reg                (0.00031 deg) 188.9655 27.9345 188.9656 27.9347

# %%
xrt_colnames1 = ['MJD', 'T_+ve', 'T_-ve', 'Rate', 'Ratepos', 'Rateneg', 'obsID'] # From full band qdp files
xrt_colnames2 = ['MJD', 'Err (pos)', 'Err(neg)', 'Rate', 'Error', 'obsID']       # From soft/hard/hr qdp files

col_names = ['SIMBAD_ID', 'LOCAL_ID', 'N_MAGHIST', 'N_UVOTSOURCE', 'N_CSV', 'SRC_REG']
print(f'{col_names[0]:<30} {col_names[1]:<20} {col_names[2]:<10} {col_names[3]:<12} {col_names[4]:<10} {col_names[5]:<10}')

all_lcs = {}
for simbad_name, local_name in source_names_dict.items():
    
    lcs = {}
    
    src_reg = src_region_dict[simbad_name]
    src_reg_stem = src_reg.split('/')[-1].split('.')[0]+'_'
    
    
    simbad_name_glob = simbad_name.translate(str.maketrans(to_replace)) # Used to fix globbing square brackets
    
    uvotsource_files = glob(f'../download_scripts/{local_name}/*uvotsource_all.fits')
    maghist_files    = glob(f'../download_scripts/{local_name}/*maghist_all.fits*')
    csv_files        = glob(f'../UKSSDC/{simbad_name_glob}/*/*/*.csv')
    
    all_tables = []
    
    for csv in csv_files:
        tab = Table.from_pandas(pd.read_csv(csv, dtype={'obsID':str}))
        all_tables.append(tab)

        if tab.colnames == xrt_colnames1:
            new_names = ['MJD', 'MJD_ERR_POS', 'MJD_ERR_NEG', 'RATE', 'RATE_ERR_POS', 'RATE_ERR_NEG', 'OBSID']
            tab.rename_columns(xrt_colnames1, new_names)
            tab['RATE_ERR'] = tab['RATE_ERR_POS'] + abs(tab['RATE_ERR_NEG'])
            
        if tab.colnames == xrt_colnames2:
            new_names = ['MJD', 'MJD_ERR_POS', 'MJD_ERR_NEG', 'RATE', 'RATE_ERR', 'OBSID']
            tab.rename_columns(xrt_colnames2, new_names)
            

        if 'curve' in csv:
            key = 'XRT_FULL'
        if 'HARD' in csv:
            key = 'XRT_HARD'
        if 'SOFT' in csv:
            key = 'XRT_SOFT'
        if 'HR' in csv:
            key = 'XRT_HR'
        if 'PC' in csv:
            key += '_PC'
        if 'WT' in csv:
            key += '_WT'
        lcs[key] = tab
        
            

    for maghist in maghist_files:
        if src_reg_stem in maghist:
            # print(src_reg_stem, maghist)
            tab = Table.read(maghist)
            for f in np.unique(tab['FILTER']):
                sub = tab[tab['FILTER'] == f]
                lcs[f'UVOT_{f}'] = sub

    all_lcs[simbad_name] = lcs
    print(f'{simbad_name:<30} {local_name:<20} {len(maghist_files):<10} {len(uvotsource_files):<12} {len(csv_files):<8} {src_reg_stem:<10}')
# Out:
# SIMBAD_ID                      LOCAL_ID             N_MAGHIST  N_UVOTSOURCE N_CSV      SRC_REG
# ESO_243-49_HLX-1               ESO243-49            1          0            4        src_
# NAME_Holmberg_IX_X-1           Ho-IX                1          1            5        src_
# Holmberg_II_X-1                Ho_II                1          2            4        src_
# M31_ULX-1                      M31_ULX-1            1          1            0        src_
# [LM2005]_NGC_598_ULX1          M33                  1          1            8        src_
# RX_J133001+47137               M51                  1          1            4        ULX7_src_
# [LM2005]_NGC_3031_ULX1         M81                  1          1            5        X6_src_
# M82_X-2                        M82                  1          1            8        src_
# [LM2005]_NGC_1042_ULX1         NGC1042              1          1            4        src_
# NAME_NGC_1313_X-1              NGC1313              3          2            4        X-1_src_
# NAME_NGC_1313_X-2              NGC1313              3          2            4        X-2_src_
# [LM2005]_NGC_247_ULX1          NGC247               1          1            4        src_
# [LB2005]_NGC_253_X20           NGC253               3          3            0        ULX3_src_
# NAME_NGC_300_ULX1              NGC300               1          1            4        src_
# [LM2005]_NGC_4395_ULX1         NGC4395              1          1            4        src_
# [LM2005]_NGC_5204_ULX1         NGC5204              1          1            4        src_
# [LM2005]_NGC_5408_ULX1         NGC5408              1          1            4        src_
# [SRW2006b]_NGC_55_ULX          NGC55                1          1            4        src_
# [SST2011]_J141939.39+564137.8  NGC5585              0          0            4        _
# NAME_NGC_5907_ULX              NGC5907              1          1            8        src_
# [LB2005]_NGC_6946_ULX1         NGC6946              1          1            4        src_
# 3XMM_J213631.9-543357          NGC7090              1          1            4        ULX3_src_
# NAME_NGC_7793_P13              NGC7793              3          1            4        src_
# NAME_NGC_925_ULX-1             NGC925               3          3            4        ULX1_src_
# NAME_NGC_925_ULX-2             NGC925               3          3            4        ULX2_src_
# SMC_X-3                        SMC_X-3              0          1            8        src_
# SS433                          SS433                1          1            8        src_
# SWIFT_J0243.6+6124             Swift_J0243.6+6124   1          1            8        src_
# NAME_UGC_6456_ULX              UGC6456              1          1            4        src_
# NOVA_Cyg_1989                  V404Cyg              1          1            8        src_
# [LB2005]_NGC_5236_ULX1         M83                  2          2            4        ulx2_src_
# NAME_M83_ULX-1                 M83                  2          2            4        ulx1_src_
# NAME_NGC_1365-X1               NGC1365              2          2            0        X1_src_
# [SK2009]_X2                    NGC1365              2          2            0        X2_src_
# NAME_IC_10_X-1                 IC10                 1          1            4        src_
# [WMR2006]_NGC4945_XMM1         NGC4945              1          1            4        X1_src_
# [LB2005]_NGC_3031_X6           M81                  1          1            8        X6_src_
# [LM2005]_NGC_4559_ULX1         NGC4559              1          1            4        src_

# %%
print('PRE-PROCESSING LIGHT CURVES...')
print('------------------------------')

colnames = ['SIMBAD_NAME', 'LC_NAME', 'LC_LENGTH','N_OBS','UVOT_EXPOSURE']
print(f'{colnames[0]:<40} {colnames[1]:<20} {colnames[2]:<10} {colnames[3]:<10} {colnames[4]:<10}')
for simbad_name, lcs in all_lcs.items():
    for lc_name, tab in lcs.items():
        
        N_obs = len(np.unique(tab['OBSID']))
        lc_len = len(tab)
        
        if 'UVOT' in lc_name:
            tab['FLAG_AB_MAG_99'] = tab['AB_MAG'] == 99
            tab['FLAG_UPPER_LIM'] = tab['NSIGMA'] < tab['MAG_LIM_SIG'] 
            tab['FLAG_AB_MAG_ERR>2'] = tab['AB_MAG_ERR'] > 2
            tab['FLAG_AB_MAG_>10_<30'] = np.logical_or((tab['AB_MAG'] < 10), (tab['AB_MAG'] > 30))
            
            nsig = 1
            sig_upper = np.mean(tab['AB_MAG']) + nsig*np.std(tab['AB_MAG'])
            sig_lower = np.mean(tab['AB_MAG']) - nsig*np.std(tab['AB_MAG'])
            tab['FLAG_AB_MAG_>1_SIG'] = np.logical_or((tab['AB_MAG'] < sig_lower), (tab['AB_MAG'] > sig_upper))
            
            uvot_exposure = sum(tab['EXPOSURE'])
        
        if 'XRT' in lc_name:
            tab['FLAG_RATE_0'] = tab['RATE'] < 0.0001
            uvot_exposure = 0
        all_lcs[simbad_name][lc_name] = tab
        

        #if N_obs > 200:
        print(f'{simbad_name:<40} {lc_name:<20} {lc_len:<10} {N_obs:<10} {uvot_exposure:.2f}')
# Out:
# PRE-PROCESSING LIGHT CURVES...
# ------------------------------
# SIMBAD_NAME                              LC_NAME              LC_LENGTH  N_OBS      UVOT_EXPOSURE
# ESO_243-49_HLX-1                         XRT_FULL_PC          146        146        0.00
# ESO_243-49_HLX-1                         XRT_HARD_PC          146        146        0.00
# ESO_243-49_HLX-1                         XRT_HR_PC            146        146        0.00
# ESO_243-49_HLX-1                         XRT_SOFT_PC          146        146        0.00
# ESO_243-49_HLX-1                         UVOT_B               1          1          95.24
# ESO_243-49_HLX-1                         UVOT_U               298        148        220603.31
# ESO_243-49_HLX-1                         UVOT_UVM2            293        153        218239.42
# ESO_243-49_HLX-1                         UVOT_UVW1            245        105        156665.12
# ESO_243-49_HLX-1                         UVOT_UVW2            639        242        504937.44
# ESO_243-49_HLX-1                         UVOT_V               1          1          95.24
# NAME_Holmberg_IX_X-1                     XRT_FULL_PC          693        693        0.00
# NAME_Holmberg_IX_X-1                     XRT_FULL_WT          1          1          0.00
# NAME_Holmberg_IX_X-1                     XRT_HARD_PC          686        686        0.00
# NAME_Holmberg_IX_X-1                     XRT_HR_PC            686        686        0.00
# NAME_Holmberg_IX_X-1                     XRT_SOFT_PC          686        686        0.00
# NAME_Holmberg_IX_X-1                     UVOT_B               235        98         15151.74
# NAME_Holmberg_IX_X-1                     UVOT_U               352        167        96394.94
# NAME_Holmberg_IX_X-1                     UVOT_UVM2            390        196        135051.92
# NAME_Holmberg_IX_X-1                     UVOT_UVW1            567        314        206953.58
# NAME_Holmberg_IX_X-1                     UVOT_UVW2            936        585        508629.27
# NAME_Holmberg_IX_X-1                     UVOT_V               227        95         14471.27
# NAME_Holmberg_IX_X-1                     UVOT_WHITE           4          1          888.44
# Holmberg_II_X-1                          XRT_FULL_PC          227        227        0.00
# Holmberg_II_X-1                          XRT_HARD_PC          227        227        0.00
# Holmberg_II_X-1                          XRT_HR_PC            227        227        0.00
# Holmberg_II_X-1                          XRT_SOFT_PC          227        227        0.00
# Holmberg_II_X-1                          UVOT_B               19         3          1113.02
# Holmberg_II_X-1                          UVOT_U               191        101        130310.08
# Holmberg_II_X-1                          UVOT_UVM2            63         34         32833.83
# Holmberg_II_X-1                          UVOT_UVW1            96         58         62507.30
# Holmberg_II_X-1                          UVOT_UVW2            84         52         57185.86
# Holmberg_II_X-1                          UVOT_V               19         3          1356.95
# M31_ULX-1                                UVOT_B               39         10         6207.23
# M31_ULX-1                                UVOT_U               229        70         164116.65
# M31_ULX-1                                UVOT_UVM2            445        151        265248.55
# M31_ULX-1                                UVOT_UVW1            1385       465        1067107.20
# M31_ULX-1                                UVOT_UVW2            542        165        352508.72
# M31_ULX-1                                UVOT_V               36         10         5477.64
# M31_ULX-1                                UVOT_WHITE           19         3          3363.40
# [LM2005]_NGC_598_ULX1                    XRT_FULL_PC          27         27         0.00
# [LM2005]_NGC_598_ULX1                    XRT_FULL_WT          1          1          0.00
# [LM2005]_NGC_598_ULX1                    XRT_HARD_PC          27         27         0.00
# [LM2005]_NGC_598_ULX1                    XRT_HARD_WT          1          1          0.00
# [LM2005]_NGC_598_ULX1                    XRT_HR_PC            27         27         0.00
# [LM2005]_NGC_598_ULX1                    XRT_HR_WT            1          1          0.00
# [LM2005]_NGC_598_ULX1                    XRT_SOFT_PC          27         27         0.00
# [LM2005]_NGC_598_ULX1                    XRT_SOFT_WT          1          1          0.00
# [LM2005]_NGC_598_ULX1                    UVOT_B               29         8          2083.98
# [LM2005]_NGC_598_ULX1                    UVOT_U               49         12         30472.63
# [LM2005]_NGC_598_ULX1                    UVOT_UVM2            75         21         20448.45
# [LM2005]_NGC_598_ULX1                    UVOT_UVW1            152        39         88945.93
# [LM2005]_NGC_598_ULX1                    UVOT_UVW2            88         24         35582.07
# [LM2005]_NGC_598_ULX1                    UVOT_V               28         8          2005.59
# RX_J133001+47137                         XRT_FULL_PC          168        168        0.00
# RX_J133001+47137                         XRT_HARD_PC          108        108        0.00
# RX_J133001+47137                         XRT_HR_PC            108        108        0.00
# RX_J133001+47137                         XRT_SOFT_PC          108        108        0.00
# RX_J133001+47137                         UVOT_B               157        69         10328.76
# RX_J133001+47137                         UVOT_U               276        123        110247.31
# RX_J133001+47137                         UVOT_UVM2            225        110        118592.63
# RX_J133001+47137                         UVOT_UVW1            253        101        100980.87
# RX_J133001+47137                         UVOT_UVW2            232        108        111067.70
# RX_J133001+47137                         UVOT_V               160        75         15714.72
# RX_J133001+47137                         UVOT_WHITE           10         1          804.74
# [LM2005]_NGC_3031_ULX1                   XRT_FULL_PC          611        611        0.00
# [LM2005]_NGC_3031_ULX1                   XRT_FULL_WT          2          2          0.00
# [LM2005]_NGC_3031_ULX1                   XRT_HARD_PC          607        607        0.00
# [LM2005]_NGC_3031_ULX1                   XRT_HR_PC            607        607        0.00
# [LM2005]_NGC_3031_ULX1                   XRT_SOFT_PC          607        607        0.00
# [LM2005]_NGC_3031_ULX1                   UVOT_B               235        98         15151.74
# [LM2005]_NGC_3031_ULX1                   UVOT_U               352        167        96394.94
# [LM2005]_NGC_3031_ULX1                   UVOT_UVM2            394        199        135898.46
# [LM2005]_NGC_3031_ULX1                   UVOT_UVW1            571        317        207881.62
# [LM2005]_NGC_3031_ULX1                   UVOT_UVW2            941        589        510728.21
# [LM2005]_NGC_3031_ULX1                   UVOT_V               227        95         14471.27
# [LM2005]_NGC_3031_ULX1                   UVOT_WHITE           4          1          888.44
# M82_X-2                                  XRT_FULL_PC          423        423        0.00
# M82_X-2                                  XRT_FULL_WT          9          9          0.00
# M82_X-2                                  XRT_HARD_PC          423        423        0.00
# M82_X-2                                  XRT_HARD_WT          9          9          0.00
# M82_X-2                                  XRT_HR_PC            423        423        0.00
# M82_X-2                                  XRT_HR_WT            9          9          0.00
# M82_X-2                                  XRT_SOFT_PC          423        423        0.00
# M82_X-2                                  XRT_SOFT_WT          9          9          0.00
# M82_X-2                                  UVOT_B               100        43         4653.28
# M82_X-2                                  UVOT_U               274        127        139918.78
# M82_X-2                                  UVOT_UVM2            422        154        245266.47
# M82_X-2                                  UVOT_UVW1            364        162        202046.38
# M82_X-2                                  UVOT_UVW2            358        157        181708.47
# M82_X-2                                  UVOT_V               92         43         3472.78
# M82_X-2                                  UVOT_WHITE           31         4          8287.23
# [LM2005]_NGC_1042_ULX1                   XRT_FULL_PC          8          8          0.00
# [LM2005]_NGC_1042_ULX1                   XRT_HARD_PC          8          8          0.00
# [LM2005]_NGC_1042_ULX1                   XRT_HR_PC            8          8          0.00
# [LM2005]_NGC_1042_ULX1                   XRT_SOFT_PC          8          8          0.00
# [LM2005]_NGC_1042_ULX1                   UVOT_B               62         14         3478.31
# [LM2005]_NGC_1042_ULX1                   UVOT_U               89         27         26035.96
# [LM2005]_NGC_1042_ULX1                   UVOT_UVM2            88         19         32152.58
# [LM2005]_NGC_1042_ULX1                   UVOT_UVW1            83         20         18204.27
# [LM2005]_NGC_1042_ULX1                   UVOT_UVW2            88         20         27584.81
# [LM2005]_NGC_1042_ULX1                   UVOT_V               59         14         3320.35
# NAME_NGC_1313_X-1                        XRT_FULL_PC          498        498        0.00
# NAME_NGC_1313_X-1                        XRT_HARD_PC          498        498        0.00
# NAME_NGC_1313_X-1                        XRT_HR_PC            498        498        0.00
# NAME_NGC_1313_X-1                        XRT_SOFT_PC          498        498        0.00
# NAME_NGC_1313_X-1                        UVOT_B               19         5          1762.23
# NAME_NGC_1313_X-1                        UVOT_U               474        285        301802.17
# NAME_NGC_1313_X-1                        UVOT_UVM2            169        98         121095.56
# NAME_NGC_1313_X-1                        UVOT_UVW1            91         56         62704.43
# NAME_NGC_1313_X-1                        UVOT_UVW2            124        67         82907.23
# NAME_NGC_1313_X-1                        UVOT_V               17         4          1530.55
# NAME_NGC_1313_X-2                        XRT_FULL_PC          452        452        0.00
# NAME_NGC_1313_X-2                        XRT_HARD_PC          452        452        0.00
# NAME_NGC_1313_X-2                        XRT_HR_PC            452        452        0.00
# NAME_NGC_1313_X-2                        XRT_SOFT_PC          452        452        0.00
# NAME_NGC_1313_X-2                        UVOT_B               19         5          1762.23
# NAME_NGC_1313_X-2                        UVOT_U               474        285        301802.17
# NAME_NGC_1313_X-2                        UVOT_UVM2            169        98         121095.56
# NAME_NGC_1313_X-2                        UVOT_UVW1            91         56         62704.43
# NAME_NGC_1313_X-2                        UVOT_UVW2            124        67         82907.23
# NAME_NGC_1313_X-2                        UVOT_V               17         4          1530.55
# [LM2005]_NGC_247_ULX1                    XRT_FULL_PC          117        117        0.00
# [LM2005]_NGC_247_ULX1                    XRT_HARD_PC          117        117        0.00
# [LM2005]_NGC_247_ULX1                    XRT_HR_PC            117        117        0.00
# [LM2005]_NGC_247_ULX1                    XRT_SOFT_PC          117        117        0.00
# [LM2005]_NGC_247_ULX1                    UVOT_B               3          1          178.47
# [LM2005]_NGC_247_ULX1                    UVOT_U               42         22         33922.34
# [LM2005]_NGC_247_ULX1                    UVOT_UVM2            135        70         61867.34
# [LM2005]_NGC_247_ULX1                    UVOT_UVW1            162        101        69116.26
# [LM2005]_NGC_247_ULX1                    UVOT_UVW2            175        109        82396.59
# [LM2005]_NGC_247_ULX1                    UVOT_V               3          1          178.48
# [LB2005]_NGC_253_X20                     UVOT_B               13         7          1124.98
# [LB2005]_NGC_253_X20                     UVOT_U               56         35         21356.41
# [LB2005]_NGC_253_X20                     UVOT_UVM2            7          6          2253.11
# [LB2005]_NGC_253_X20                     UVOT_UVW1            20         9          8393.88
# [LB2005]_NGC_253_X20                     UVOT_UVW2            13         7          4022.45
# [LB2005]_NGC_253_X20                     UVOT_V               8          7          653.74
# NAME_NGC_300_ULX1                        XRT_FULL_PC          71         71         0.00
# NAME_NGC_300_ULX1                        XRT_HARD_PC          71         71         0.00
# NAME_NGC_300_ULX1                        XRT_HR_PC            71         71         0.00
# NAME_NGC_300_ULX1                        XRT_SOFT_PC          71         71         0.00
# NAME_NGC_300_ULX1                        UVOT_B               183        50         24346.31
# NAME_NGC_300_ULX1                        UVOT_U               233        66         92340.22
# NAME_NGC_300_ULX1                        UVOT_UVM2            185        59         123113.58
# NAME_NGC_300_ULX1                        UVOT_UVW1            261        73         145508.73
# NAME_NGC_300_ULX1                        UVOT_UVW2            237        71         145037.30
# NAME_NGC_300_ULX1                        UVOT_V               155        46         18525.43
# [LM2005]_NGC_4395_ULX1                   XRT_FULL_PC          143        143        0.00
# [LM2005]_NGC_4395_ULX1                   XRT_HARD_PC          143        143        0.00
# [LM2005]_NGC_4395_ULX1                   XRT_HR_PC            143        143        0.00
# [LM2005]_NGC_4395_ULX1                   XRT_SOFT_PC          143        143        0.00
# [LM2005]_NGC_4395_ULX1                   UVOT_B               260        138        56547.69
# [LM2005]_NGC_4395_ULX1                   UVOT_U               244        144        35735.92
# [LM2005]_NGC_4395_ULX1                   UVOT_UVM2            49         43         40335.30
# [LM2005]_NGC_4395_ULX1                   UVOT_UVW1            18         14         13468.43
# [LM2005]_NGC_4395_ULX1                   UVOT_UVW2            277        174        140421.24
# [LM2005]_NGC_4395_ULX1                   UVOT_V               232        135        24212.30
# [LM2005]_NGC_5204_ULX1                   XRT_FULL_PC          64         64         0.00
# [LM2005]_NGC_5204_ULX1                   XRT_HARD_PC          64         64         0.00
# [LM2005]_NGC_5204_ULX1                   XRT_HR_PC            64         64         0.00
# [LM2005]_NGC_5204_ULX1                   XRT_SOFT_PC          64         64         0.00
# [LM2005]_NGC_5204_ULX1                   UVOT_U               82         35         94597.42
# [LM2005]_NGC_5204_ULX1                   UVOT_UVM2            41         21         22614.86
# [LM2005]_NGC_5204_ULX1                   UVOT_UVW1            28         17         13227.12
# [LM2005]_NGC_5204_ULX1                   UVOT_UVW2            37         19         22129.80
# [LM2005]_NGC_5408_ULX1                   XRT_FULL_PC          479        479        0.00
# [LM2005]_NGC_5408_ULX1                   XRT_HARD_PC          479        479        0.00
# [LM2005]_NGC_5408_ULX1                   XRT_HR_PC            479        479        0.00
# [LM2005]_NGC_5408_ULX1                   XRT_SOFT_PC          479        479        0.00
# [LM2005]_NGC_5408_ULX1                   UVOT_UVM2            192        147        139392.22
# [SRW2006b]_NGC_55_ULX                    XRT_FULL_PC          166        166        0.00
# [SRW2006b]_NGC_55_ULX                    XRT_HARD_PC          166        166        0.00
# [SRW2006b]_NGC_55_ULX                    XRT_HR_PC            166        166        0.00
# [SRW2006b]_NGC_55_ULX                    XRT_SOFT_PC          166        166        0.00
# [SRW2006b]_NGC_55_ULX                    UVOT_B               7          3          67.30
# [SRW2006b]_NGC_55_ULX                    UVOT_U               48         25         40723.46
# [SRW2006b]_NGC_55_ULX                    UVOT_UVM2            71         31         50368.00
# [SRW2006b]_NGC_55_ULX                    UVOT_UVW1            86         49         52127.95
# [SRW2006b]_NGC_55_ULX                    UVOT_UVW2            74         42         42666.09
# [SRW2006b]_NGC_55_ULX                    UVOT_V               6          3          57.66
# [SST2011]_J141939.39+564137.8            XRT_FULL_PC          2          2          0.00
# [SST2011]_J141939.39+564137.8            XRT_HARD_PC          2          2          0.00
# [SST2011]_J141939.39+564137.8            XRT_HR_PC            2          2          0.00
# [SST2011]_J141939.39+564137.8            XRT_SOFT_PC          2          2          0.00
# NAME_NGC_5907_ULX                        XRT_FULL_PC          72         72         0.00
# NAME_NGC_5907_ULX                        XRT_FULL_WT          1          1          0.00
# NAME_NGC_5907_ULX                        XRT_HARD_PC          72         72         0.00
# NAME_NGC_5907_ULX                        XRT_HARD_WT          1          1          0.00
# NAME_NGC_5907_ULX                        XRT_HR_PC            72         72         0.00
# NAME_NGC_5907_ULX                        XRT_HR_WT            1          1          0.00
# NAME_NGC_5907_ULX                        XRT_SOFT_PC          72         72         0.00
# NAME_NGC_5907_ULX                        XRT_SOFT_WT          1          1          0.00
# NAME_NGC_5907_ULX                        UVOT_U               288        147        242833.54
# NAME_NGC_5907_ULX                        UVOT_UVM2            298        161        265164.55
# NAME_NGC_5907_ULX                        UVOT_UVW1            228        113        178090.76
# NAME_NGC_5907_ULX                        UVOT_UVW2            257        118        195118.25
# [LB2005]_NGC_6946_ULX1                   XRT_FULL_PC          2          2          0.00
# [LB2005]_NGC_6946_ULX1                   XRT_HARD_PC          2          2          0.00
# [LB2005]_NGC_6946_ULX1                   XRT_HR_PC            2          2          0.00
# [LB2005]_NGC_6946_ULX1                   XRT_SOFT_PC          2          2          0.00
# [LB2005]_NGC_6946_ULX1                   UVOT_B               148        96         15817.44
# [LB2005]_NGC_6946_ULX1                   UVOT_U               159        101        17048.78
# [LB2005]_NGC_6946_ULX1                   UVOT_UVM2            146        98         28960.94
# [LB2005]_NGC_6946_ULX1                   UVOT_UVW1            162        102        22488.74
# [LB2005]_NGC_6946_ULX1                   UVOT_UVW2            148        100        25848.95
# [LB2005]_NGC_6946_ULX1                   UVOT_V               155        100        14817.42
# 3XMM_J213631.9-543357                    XRT_FULL_PC          1          1          0.00
# 3XMM_J213631.9-543357                    XRT_HARD_PC          1          1          0.00
# 3XMM_J213631.9-543357                    XRT_HR_PC            1          1          0.00
# 3XMM_J213631.9-543357                    XRT_SOFT_PC          1          1          0.00
# 3XMM_J213631.9-543357                    UVOT_B               7          2          518.15
# 3XMM_J213631.9-543357                    UVOT_U               48         12         32702.20
# 3XMM_J213631.9-543357                    UVOT_UVM2            53         12         32523.08
# 3XMM_J213631.9-543357                    UVOT_UVW1            23         10         14978.08
# 3XMM_J213631.9-543357                    UVOT_UVW2            23         9          12757.98
# 3XMM_J213631.9-543357                    UVOT_V               5          2          268.54
# NAME_NGC_7793_P13                        XRT_FULL_PC          223        223        0.00
# NAME_NGC_7793_P13                        XRT_HARD_PC          223        223        0.00
# NAME_NGC_7793_P13                        XRT_HR_PC            223        223        0.00
# NAME_NGC_7793_P13                        XRT_SOFT_PC          223        223        0.00
# NAME_NGC_7793_P13                        UVOT_B               2          2          206.24
# NAME_NGC_7793_P13                        UVOT_U               444        260        362244.97
# NAME_NGC_7793_P13                        UVOT_UVM2            62         27         42427.18
# NAME_NGC_7793_P13                        UVOT_UVW1            49         22         31702.88
# NAME_NGC_7793_P13                        UVOT_UVW2            53         21         38136.33
# NAME_NGC_7793_P13                        UVOT_V               2          2          206.24
# NAME_NGC_925_ULX-1                       XRT_FULL_PC          91         91         0.00
# NAME_NGC_925_ULX-1                       XRT_HARD_PC          91         91         0.00
# NAME_NGC_925_ULX-1                       XRT_HR_PC            91         91         0.00
# NAME_NGC_925_ULX-1                       XRT_SOFT_PC          91         91         0.00
# NAME_NGC_925_ULX-1                       UVOT_U               35         16         28460.93
# NAME_NGC_925_ULX-1                       UVOT_UVM2            78         29         40919.95
# NAME_NGC_925_ULX-1                       UVOT_UVW1            107        41         65280.87
# NAME_NGC_925_ULX-1                       UVOT_UVW2            109        41         66509.36
# NAME_NGC_925_ULX-2                       XRT_FULL_PC          39         39         0.00
# NAME_NGC_925_ULX-2                       XRT_HARD_PC          39         39         0.00
# NAME_NGC_925_ULX-2                       XRT_HR_PC            39         39         0.00
# NAME_NGC_925_ULX-2                       XRT_SOFT_PC          39         39         0.00
# NAME_NGC_925_ULX-2                       UVOT_U               35         16         28460.93
# NAME_NGC_925_ULX-2                       UVOT_UVM2            78         29         40919.95
# NAME_NGC_925_ULX-2                       UVOT_UVW1            107        41         65280.87
# NAME_NGC_925_ULX-2                       UVOT_UVW2            109        41         66509.36
# SMC_X-3                                  XRT_FULL_PC          89         89         0.00
# SMC_X-3                                  XRT_FULL_WT          67         67         0.00
# SMC_X-3                                  XRT_HARD_PC          89         89         0.00
# SMC_X-3                                  XRT_HARD_WT          67         67         0.00
# SMC_X-3                                  XRT_HR_PC            89         89         0.00
# SMC_X-3                                  XRT_HR_WT            67         67         0.00
# SMC_X-3                                  XRT_SOFT_PC          89         89         0.00
# SMC_X-3                                  XRT_SOFT_WT          67         67         0.00
# SS433                                    XRT_FULL_PC          22         22         0.00
# SS433                                    XRT_FULL_WT          18         18         0.00
# SS433                                    XRT_HARD_PC          22         22         0.00
# SS433                                    XRT_HARD_WT          18         18         0.00
# SS433                                    XRT_HR_PC            22         22         0.00
# SS433                                    XRT_HR_WT            18         18         0.00
# SS433                                    XRT_SOFT_PC          22         22         0.00
# SS433                                    XRT_SOFT_WT          18         18         0.00
# SS433                                    UVOT_B               30         7          2079.03
# SS433                                    UVOT_U               42         14         10474.66
# SS433                                    UVOT_UVM2            39         13         13614.58
# SS433                                    UVOT_UVW1            46         16         14835.88
# SS433                                    UVOT_UVW2            37         13         12351.69
# SS433                                    UVOT_V               30         8          2237.97
# SWIFT_J0243.6+6124                       XRT_FULL_PC          44         44         0.00
# SWIFT_J0243.6+6124                       XRT_FULL_WT          70         70         0.00
# SWIFT_J0243.6+6124                       XRT_HARD_PC          44         44         0.00
# SWIFT_J0243.6+6124                       XRT_HARD_WT          70         70         0.00
# SWIFT_J0243.6+6124                       XRT_HR_PC            44         44         0.00
# SWIFT_J0243.6+6124                       XRT_HR_WT            70         70         0.00
# SWIFT_J0243.6+6124                       XRT_SOFT_PC          44         44         0.00
# SWIFT_J0243.6+6124                       XRT_SOFT_WT          70         70         0.00
# SWIFT_J0243.6+6124                       UVOT_B               114        42         6907.43
# SWIFT_J0243.6+6124                       UVOT_U               199        77         58761.09
# SWIFT_J0243.6+6124                       UVOT_UVM2            179        89         59248.87
# SWIFT_J0243.6+6124                       UVOT_UVW1            203        85         68986.98
# SWIFT_J0243.6+6124                       UVOT_UVW2            192        90         62513.52
# SWIFT_J0243.6+6124                       UVOT_V               122        46         6951.88
# SWIFT_J0243.6+6124                       UVOT_WHITE           15         2          1156.71
# NAME_UGC_6456_ULX                        XRT_FULL_PC          12         12         0.00
# NAME_UGC_6456_ULX                        XRT_HARD_PC          12         12         0.00
# NAME_UGC_6456_ULX                        XRT_HR_PC            12         12         0.00
# NAME_UGC_6456_ULX                        XRT_SOFT_PC          12         12         0.00
# NAME_UGC_6456_ULX                        UVOT_B               16         5          4160.76
# NAME_UGC_6456_ULX                        UVOT_U               14         7          9207.13
# NAME_UGC_6456_ULX                        UVOT_UVM2            35         14         13971.20
# NAME_UGC_6456_ULX                        UVOT_UVW1            30         14         12640.98
# NAME_UGC_6456_ULX                        UVOT_UVW2            28         12         11105.07
# NAME_UGC_6456_ULX                        UVOT_V               2          1          145.23
# NOVA_Cyg_1989                            XRT_FULL_PC          129        129        0.00
# NOVA_Cyg_1989                            XRT_FULL_WT          33         33         0.00
# NOVA_Cyg_1989                            XRT_HARD_PC          100        100        0.00
# NOVA_Cyg_1989                            XRT_HARD_WT          33         33         0.00
# NOVA_Cyg_1989                            XRT_HR_PC            100        100        0.00
# NOVA_Cyg_1989                            XRT_HR_WT            33         33         0.00
# NOVA_Cyg_1989                            XRT_SOFT_PC          100        100        0.00
# NOVA_Cyg_1989                            XRT_SOFT_WT          33         33         0.00
# NOVA_Cyg_1989                            UVOT_B               47         26         3876.27
# NOVA_Cyg_1989                            UVOT_U               178        109        115149.37
# NOVA_Cyg_1989                            UVOT_UVM2            72         41         23624.27
# NOVA_Cyg_1989                            UVOT_UVW1            274        94         221212.44
# NOVA_Cyg_1989                            UVOT_UVW2            63         37         18395.18
# NOVA_Cyg_1989                            UVOT_V               47         27         3959.04
# NOVA_Cyg_1989                            UVOT_WHITE           51         24         7320.48
# [LB2005]_NGC_5236_ULX1                   XRT_FULL_PC          60         60         0.00
# [LB2005]_NGC_5236_ULX1                   XRT_HARD_PC          60         60         0.00
# [LB2005]_NGC_5236_ULX1                   XRT_HR_PC            60         60         0.00
# [LB2005]_NGC_5236_ULX1                   XRT_SOFT_PC          60         60         0.00
# [LB2005]_NGC_5236_ULX1                   UVOT_B               19         9          1349.62
# [LB2005]_NGC_5236_ULX1                   UVOT_U               88         41         61635.46
# [LB2005]_NGC_5236_ULX1                   UVOT_UVM2            64         40         43826.52
# [LB2005]_NGC_5236_ULX1                   UVOT_UVW1            46         29         23183.66
# [LB2005]_NGC_5236_ULX1                   UVOT_UVW2            46         27         29499.75
# [LB2005]_NGC_5236_ULX1                   UVOT_V               16         9          1570.41
# NAME_M83_ULX-1                           XRT_FULL_PC          38         38         0.00
# NAME_M83_ULX-1                           XRT_HARD_PC          38         38         0.00
# NAME_M83_ULX-1                           XRT_HR_PC            38         38         0.00
# NAME_M83_ULX-1                           XRT_SOFT_PC          38         38         0.00
# NAME_M83_ULX-1                           UVOT_B               19         9          1349.62
# NAME_M83_ULX-1                           UVOT_U               88         41         61635.46
# NAME_M83_ULX-1                           UVOT_UVM2            64         40         43826.52
# NAME_M83_ULX-1                           UVOT_UVW1            46         29         23183.66
# NAME_M83_ULX-1                           UVOT_UVW2            46         27         29499.75
# NAME_M83_ULX-1                           UVOT_V               16         9          1570.41
# NAME_NGC_1365-X1                         UVOT_B               124        63         6829.15
# NAME_NGC_1365-X1                         UVOT_U               161        77         25686.28
# NAME_NGC_1365-X1                         UVOT_UVM2            214        98         100580.95
# NAME_NGC_1365-X1                         UVOT_UVW1            148        61         40852.83
# NAME_NGC_1365-X1                         UVOT_UVW2            190        62         47406.47
# NAME_NGC_1365-X1                         UVOT_V               118        61         5552.11
# NAME_NGC_1365-X1                         UVOT_WHITE           12         1          1428.36
# [SK2009]_X2                              UVOT_B               124        63         6829.15
# [SK2009]_X2                              UVOT_U               161        77         25686.28
# [SK2009]_X2                              UVOT_UVM2            214        98         100580.95
# [SK2009]_X2                              UVOT_UVW1            148        61         40852.83
# [SK2009]_X2                              UVOT_UVW2            190        62         47406.47
# [SK2009]_X2                              UVOT_V               118        61         5552.11
# [SK2009]_X2                              UVOT_WHITE           12         1          1428.36
# NAME_IC_10_X-1                           XRT_FULL_PC          103        103        0.00
# NAME_IC_10_X-1                           XRT_HARD_PC          103        103        0.00
# NAME_IC_10_X-1                           XRT_HR_PC            103        103        0.00
# NAME_IC_10_X-1                           XRT_SOFT_PC          103        103        0.00
# NAME_IC_10_X-1                           UVOT_U               253        119        185702.22
# NAME_IC_10_X-1                           UVOT_UVM2            35         5          25255.62
# NAME_IC_10_X-1                           UVOT_UVW1            25         3          19651.12
# NAME_IC_10_X-1                           UVOT_UVW2            37         3          28760.80
# [WMR2006]_NGC4945_XMM1                   XRT_FULL_PC          50         50         0.00
# [WMR2006]_NGC4945_XMM1                   XRT_HARD_PC          50         50         0.00
# [WMR2006]_NGC4945_XMM1                   XRT_HR_PC            50         50         0.00
# [WMR2006]_NGC4945_XMM1                   XRT_SOFT_PC          50         50         0.00
# [WMR2006]_NGC4945_XMM1                   UVOT_B               10         3          694.50
# [WMR2006]_NGC4945_XMM1                   UVOT_U               10         3          694.57
# [WMR2006]_NGC4945_XMM1                   UVOT_UVM2            71         42         48109.39
# [WMR2006]_NGC4945_XMM1                   UVOT_UVW1            55         32         28252.90
# [WMR2006]_NGC4945_XMM1                   UVOT_UVW2            76         46         46854.91
# [WMR2006]_NGC4945_XMM1                   UVOT_V               9          3          625.92
# [LB2005]_NGC_3031_X6                     XRT_FULL_PC          19         19         0.00
# [LB2005]_NGC_3031_X6                     XRT_FULL_WT          1          1          0.00
# [LB2005]_NGC_3031_X6                     XRT_HARD_PC          19         19         0.00
# [LB2005]_NGC_3031_X6                     XRT_HARD_WT          1          1          0.00
# [LB2005]_NGC_3031_X6                     XRT_HR_PC            19         19         0.00
# [LB2005]_NGC_3031_X6                     XRT_HR_WT            1          1          0.00
# [LB2005]_NGC_3031_X6                     XRT_SOFT_PC          19         19         0.00
# [LB2005]_NGC_3031_X6                     XRT_SOFT_WT          1          1          0.00
# [LB2005]_NGC_3031_X6                     UVOT_B               235        98         15151.74
# [LB2005]_NGC_3031_X6                     UVOT_U               352        167        96394.94
# [LB2005]_NGC_3031_X6                     UVOT_UVM2            394        199        135898.46
# [LB2005]_NGC_3031_X6                     UVOT_UVW1            571        317        207881.62
# [LB2005]_NGC_3031_X6                     UVOT_UVW2            941        589        510728.21
# [LB2005]_NGC_3031_X6                     UVOT_V               227        95         14471.27
# [LB2005]_NGC_3031_X6                     UVOT_WHITE           4          1          888.44
# [LM2005]_NGC_4559_ULX1                   XRT_FULL_PC          89         89         0.00
# [LM2005]_NGC_4559_ULX1                   XRT_HARD_PC          89         89         0.00
# [LM2005]_NGC_4559_ULX1                   XRT_HR_PC            89         89         0.00
# [LM2005]_NGC_4559_ULX1                   XRT_SOFT_PC          89         89         0.00
# [LM2005]_NGC_4559_ULX1                   UVOT_B               31         7          1653.36
# [LM2005]_NGC_4559_ULX1                   UVOT_U               54         22         18245.91
# [LM2005]_NGC_4559_ULX1                   UVOT_UVM2            44         19         23348.20
# [LM2005]_NGC_4559_ULX1                   UVOT_UVW1            86         55         41484.64
# [LM2005]_NGC_4559_ULX1                   UVOT_UVW2            95         56         48325.13
# [LM2005]_NGC_4559_ULX1                   UVOT_V               28         7          1393.22

# %%
print('APPLYING FILTER FLAGS')
print('---------------------')

for simbad_name, lcs in all_lcs.items():
    for lc_name, tab in lcs.items():
        if 'UVOT' in lc_name:
            flags = ['FLAG_AB_MAG_99', 'FLAG_UPPER_LIM', 'FLAG_AB_MAG_>10_<30', 'FLAG_AB_MAG_ERR>2', 'FLAG_AB_MAG_>1_SIG', ]
            colors = ['red', 'blue', 'purple', 'green']

        elif 'XRT' in lc_name:
            flags = ['FLAG_RATE_0']
            colors = ['green']

            #plt.figure(figsize=(20,5))
            #plt.errorbar(tab['MET'], tab['AB_MAG'], yerr=tab['AB_MAG_ERR'], ls='none', lw=1.0, capsize=1.0, marker='.')

            
        for i, flag in enumerate(flags):
            rows_pre = len(tab)
            tab = tab[~tab[flag]]
            all_lcs[simbad_name][lc_name] = tab
            print(f'{simbad_name:<40}{lc_name:<20}{flag:<20} pre={rows_pre:<5} post={len(tab):<5} diff={rows_pre-len(tab):<5}')

            #plt.figure(figsize=(20,5))
            #plt.title(f'{simbad_name:<40}{lc_name:<20}{flag:<20} \n pre={rows_pre:<5} post={len(tab):<5} diff={rows_pre-len(tab):<5}')
            #plt.errorbar(tab['MET'], tab['AB_MAG'], yerr=tab['AB_MAG_ERR'], ls='none', lw=1.0, capsize=1.0, marker='.', color=colors[i])
            #plt.show()
# Out:
# APPLYING FILTER FLAGS
# ---------------------
# ESO_243-49_HLX-1                        XRT_FULL_PC         FLAG_RATE_0          pre=146   post=144   diff=2
# ESO_243-49_HLX-1                        XRT_HARD_PC         FLAG_RATE_0          pre=146   post=124   diff=22
# ESO_243-49_HLX-1                        XRT_HR_PC           FLAG_RATE_0          pre=146   post=126   diff=20
# ESO_243-49_HLX-1                        XRT_SOFT_PC         FLAG_RATE_0          pre=146   post=144   diff=2
# ESO_243-49_HLX-1                        UVOT_B              FLAG_AB_MAG_99       pre=1     post=1     diff=0
# ESO_243-49_HLX-1                        UVOT_B              FLAG_UPPER_LIM       pre=1     post=1     diff=0
# ESO_243-49_HLX-1                        UVOT_B              FLAG_AB_MAG_>10_<30  pre=1     post=1     diff=0
# ESO_243-49_HLX-1                        UVOT_B              FLAG_AB_MAG_ERR>2    pre=1     post=1     diff=0
# ESO_243-49_HLX-1                        UVOT_B              FLAG_AB_MAG_>1_SIG   pre=1     post=1     diff=0
# ESO_243-49_HLX-1                        UVOT_U              FLAG_AB_MAG_99       pre=298   post=281   diff=17
# ESO_243-49_HLX-1                        UVOT_U              FLAG_UPPER_LIM       pre=281   post=281   diff=0
# ESO_243-49_HLX-1                        UVOT_U              FLAG_AB_MAG_>10_<30  pre=281   post=281   diff=0
# ESO_243-49_HLX-1                        UVOT_U              FLAG_AB_MAG_ERR>2    pre=281   post=281   diff=0
# ESO_243-49_HLX-1                        UVOT_U              FLAG_AB_MAG_>1_SIG   pre=281   post=281   diff=0
# ESO_243-49_HLX-1                        UVOT_UVM2           FLAG_AB_MAG_99       pre=293   post=279   diff=14
# ESO_243-49_HLX-1                        UVOT_UVM2           FLAG_UPPER_LIM       pre=279   post=250   diff=29
# ESO_243-49_HLX-1                        UVOT_UVM2           FLAG_AB_MAG_>10_<30  pre=250   post=250   diff=0
# ESO_243-49_HLX-1                        UVOT_UVM2           FLAG_AB_MAG_ERR>2    pre=250   post=250   diff=0
# ESO_243-49_HLX-1                        UVOT_UVM2           FLAG_AB_MAG_>1_SIG   pre=250   post=250   diff=0
# ESO_243-49_HLX-1                        UVOT_UVW1           FLAG_AB_MAG_99       pre=245   post=221   diff=24
# ESO_243-49_HLX-1                        UVOT_UVW1           FLAG_UPPER_LIM       pre=221   post=215   diff=6
# ESO_243-49_HLX-1                        UVOT_UVW1           FLAG_AB_MAG_>10_<30  pre=215   post=215   diff=0
# ESO_243-49_HLX-1                        UVOT_UVW1           FLAG_AB_MAG_ERR>2    pre=215   post=215   diff=0
# ESO_243-49_HLX-1                        UVOT_UVW1           FLAG_AB_MAG_>1_SIG   pre=215   post=215   diff=0
# ESO_243-49_HLX-1                        UVOT_UVW2           FLAG_AB_MAG_99       pre=639   post=615   diff=24
# ESO_243-49_HLX-1                        UVOT_UVW2           FLAG_UPPER_LIM       pre=615   post=596   diff=19
# ESO_243-49_HLX-1                        UVOT_UVW2           FLAG_AB_MAG_>10_<30  pre=596   post=596   diff=0
# ESO_243-49_HLX-1                        UVOT_UVW2           FLAG_AB_MAG_ERR>2    pre=596   post=596   diff=0
# ESO_243-49_HLX-1                        UVOT_UVW2           FLAG_AB_MAG_>1_SIG   pre=596   post=596   diff=0
# ESO_243-49_HLX-1                        UVOT_V              FLAG_AB_MAG_99       pre=1     post=1     diff=0
# ESO_243-49_HLX-1                        UVOT_V              FLAG_UPPER_LIM       pre=1     post=1     diff=0
# ESO_243-49_HLX-1                        UVOT_V              FLAG_AB_MAG_>10_<30  pre=1     post=1     diff=0
# ESO_243-49_HLX-1                        UVOT_V              FLAG_AB_MAG_ERR>2    pre=1     post=1     diff=0
# ESO_243-49_HLX-1                        UVOT_V              FLAG_AB_MAG_>1_SIG   pre=1     post=1     diff=0
# NAME_Holmberg_IX_X-1                    XRT_FULL_PC         FLAG_RATE_0          pre=693   post=689   diff=4
# NAME_Holmberg_IX_X-1                    XRT_FULL_WT         FLAG_RATE_0          pre=1     post=1     diff=0
# NAME_Holmberg_IX_X-1                    XRT_HARD_PC         FLAG_RATE_0          pre=686   post=683   diff=3
# NAME_Holmberg_IX_X-1                    XRT_HR_PC           FLAG_RATE_0          pre=686   post=686   diff=0
# NAME_Holmberg_IX_X-1                    XRT_SOFT_PC         FLAG_RATE_0          pre=686   post=683   diff=3
# NAME_Holmberg_IX_X-1                    UVOT_B              FLAG_AB_MAG_99       pre=235   post=88    diff=147
# NAME_Holmberg_IX_X-1                    UVOT_B              FLAG_UPPER_LIM       pre=88    post=1     diff=87
# NAME_Holmberg_IX_X-1                    UVOT_B              FLAG_AB_MAG_>10_<30  pre=1     post=1     diff=0
# NAME_Holmberg_IX_X-1                    UVOT_B              FLAG_AB_MAG_ERR>2    pre=1     post=1     diff=0
# NAME_Holmberg_IX_X-1                    UVOT_B              FLAG_AB_MAG_>1_SIG   pre=1     post=0     diff=1
# NAME_Holmberg_IX_X-1                    UVOT_U              FLAG_AB_MAG_99       pre=352   post=163   diff=189
# NAME_Holmberg_IX_X-1                    UVOT_U              FLAG_UPPER_LIM       pre=163   post=6     diff=157
# NAME_Holmberg_IX_X-1                    UVOT_U              FLAG_AB_MAG_>10_<30  pre=6     post=6     diff=0
# NAME_Holmberg_IX_X-1                    UVOT_U              FLAG_AB_MAG_ERR>2    pre=6     post=6     diff=0
# NAME_Holmberg_IX_X-1                    UVOT_U              FLAG_AB_MAG_>1_SIG   pre=6     post=0     diff=6
# NAME_Holmberg_IX_X-1                    UVOT_UVM2           FLAG_AB_MAG_99       pre=390   post=164   diff=226
# NAME_Holmberg_IX_X-1                    UVOT_UVM2           FLAG_UPPER_LIM       pre=164   post=3     diff=161
# NAME_Holmberg_IX_X-1                    UVOT_UVM2           FLAG_AB_MAG_>10_<30  pre=3     post=3     diff=0
# NAME_Holmberg_IX_X-1                    UVOT_UVM2           FLAG_AB_MAG_ERR>2    pre=3     post=3     diff=0
# NAME_Holmberg_IX_X-1                    UVOT_UVM2           FLAG_AB_MAG_>1_SIG   pre=3     post=0     diff=3
# NAME_Holmberg_IX_X-1                    UVOT_UVW1           FLAG_AB_MAG_99       pre=567   post=314   diff=253
# NAME_Holmberg_IX_X-1                    UVOT_UVW1           FLAG_UPPER_LIM       pre=314   post=12    diff=302
# NAME_Holmberg_IX_X-1                    UVOT_UVW1           FLAG_AB_MAG_>10_<30  pre=12    post=12    diff=0
# NAME_Holmberg_IX_X-1                    UVOT_UVW1           FLAG_AB_MAG_ERR>2    pre=12    post=12    diff=0
# NAME_Holmberg_IX_X-1                    UVOT_UVW1           FLAG_AB_MAG_>1_SIG   pre=12    post=12    diff=0
# NAME_Holmberg_IX_X-1                    UVOT_UVW2           FLAG_AB_MAG_99       pre=936   post=520   diff=416
# NAME_Holmberg_IX_X-1                    UVOT_UVW2           FLAG_UPPER_LIM       pre=520   post=14    diff=506
# NAME_Holmberg_IX_X-1                    UVOT_UVW2           FLAG_AB_MAG_>10_<30  pre=14    post=14    diff=0
# NAME_Holmberg_IX_X-1                    UVOT_UVW2           FLAG_AB_MAG_ERR>2    pre=14    post=14    diff=0
# NAME_Holmberg_IX_X-1                    UVOT_UVW2           FLAG_AB_MAG_>1_SIG   pre=14    post=14    diff=0
# NAME_Holmberg_IX_X-1                    UVOT_V              FLAG_AB_MAG_99       pre=227   post=85    diff=142
# NAME_Holmberg_IX_X-1                    UVOT_V              FLAG_UPPER_LIM       pre=85    post=1     diff=84
# NAME_Holmberg_IX_X-1                    UVOT_V              FLAG_AB_MAG_>10_<30  pre=1     post=1     diff=0
# NAME_Holmberg_IX_X-1                    UVOT_V              FLAG_AB_MAG_ERR>2    pre=1     post=1     diff=0
# NAME_Holmberg_IX_X-1                    UVOT_V              FLAG_AB_MAG_>1_SIG   pre=1     post=0     diff=1
# NAME_Holmberg_IX_X-1                    UVOT_WHITE          FLAG_AB_MAG_99       pre=4     post=0     diff=4
# NAME_Holmberg_IX_X-1                    UVOT_WHITE          FLAG_UPPER_LIM       pre=0     post=0     diff=0
# NAME_Holmberg_IX_X-1                    UVOT_WHITE          FLAG_AB_MAG_>10_<30  pre=0     post=0     diff=0
# NAME_Holmberg_IX_X-1                    UVOT_WHITE          FLAG_AB_MAG_ERR>2    pre=0     post=0     diff=0
# NAME_Holmberg_IX_X-1                    UVOT_WHITE          FLAG_AB_MAG_>1_SIG   pre=0     post=0     diff=0
# Holmberg_II_X-1                         XRT_FULL_PC         FLAG_RATE_0          pre=227   post=220   diff=7
# Holmberg_II_X-1                         XRT_HARD_PC         FLAG_RATE_0          pre=227   post=220   diff=7
# Holmberg_II_X-1                         XRT_HR_PC           FLAG_RATE_0          pre=227   post=227   diff=0
# Holmberg_II_X-1                         XRT_SOFT_PC         FLAG_RATE_0          pre=227   post=220   diff=7
# Holmberg_II_X-1                         UVOT_B              FLAG_AB_MAG_99       pre=19    post=19    diff=0
# Holmberg_II_X-1                         UVOT_B              FLAG_UPPER_LIM       pre=19    post=19    diff=0
# Holmberg_II_X-1                         UVOT_B              FLAG_AB_MAG_>10_<30  pre=19    post=19    diff=0
# Holmberg_II_X-1                         UVOT_B              FLAG_AB_MAG_ERR>2    pre=19    post=19    diff=0
# Holmberg_II_X-1                         UVOT_B              FLAG_AB_MAG_>1_SIG   pre=19    post=12    diff=7
# Holmberg_II_X-1                         UVOT_U              FLAG_AB_MAG_99       pre=191   post=191   diff=0
# Holmberg_II_X-1                         UVOT_U              FLAG_UPPER_LIM       pre=191   post=191   diff=0
# Holmberg_II_X-1                         UVOT_U              FLAG_AB_MAG_>10_<30  pre=191   post=191   diff=0
# Holmberg_II_X-1                         UVOT_U              FLAG_AB_MAG_ERR>2    pre=191   post=191   diff=0
# Holmberg_II_X-1                         UVOT_U              FLAG_AB_MAG_>1_SIG   pre=191   post=134   diff=57
# Holmberg_II_X-1                         UVOT_UVM2           FLAG_AB_MAG_99       pre=63    post=63    diff=0
# Holmberg_II_X-1                         UVOT_UVM2           FLAG_UPPER_LIM       pre=63    post=63    diff=0
# Holmberg_II_X-1                         UVOT_UVM2           FLAG_AB_MAG_>10_<30  pre=63    post=63    diff=0
# Holmberg_II_X-1                         UVOT_UVM2           FLAG_AB_MAG_ERR>2    pre=63    post=63    diff=0
# Holmberg_II_X-1                         UVOT_UVM2           FLAG_AB_MAG_>1_SIG   pre=63    post=46    diff=17
# Holmberg_II_X-1                         UVOT_UVW1           FLAG_AB_MAG_99       pre=96    post=96    diff=0
# Holmberg_II_X-1                         UVOT_UVW1           FLAG_UPPER_LIM       pre=96    post=96    diff=0
# Holmberg_II_X-1                         UVOT_UVW1           FLAG_AB_MAG_>10_<30  pre=96    post=96    diff=0
# Holmberg_II_X-1                         UVOT_UVW1           FLAG_AB_MAG_ERR>2    pre=96    post=96    diff=0
# Holmberg_II_X-1                         UVOT_UVW1           FLAG_AB_MAG_>1_SIG   pre=96    post=76    diff=20
# Holmberg_II_X-1                         UVOT_UVW2           FLAG_AB_MAG_99       pre=84    post=84    diff=0
# Holmberg_II_X-1                         UVOT_UVW2           FLAG_UPPER_LIM       pre=84    post=84    diff=0
# Holmberg_II_X-1                         UVOT_UVW2           FLAG_AB_MAG_>10_<30  pre=84    post=84    diff=0
# Holmberg_II_X-1                         UVOT_UVW2           FLAG_AB_MAG_ERR>2    pre=84    post=84    diff=0
# Holmberg_II_X-1                         UVOT_UVW2           FLAG_AB_MAG_>1_SIG   pre=84    post=64    diff=20
# Holmberg_II_X-1                         UVOT_V              FLAG_AB_MAG_99       pre=19    post=19    diff=0
# Holmberg_II_X-1                         UVOT_V              FLAG_UPPER_LIM       pre=19    post=18    diff=1
# Holmberg_II_X-1                         UVOT_V              FLAG_AB_MAG_>10_<30  pre=18    post=18    diff=0
# Holmberg_II_X-1                         UVOT_V              FLAG_AB_MAG_ERR>2    pre=18    post=18    diff=0
# Holmberg_II_X-1                         UVOT_V              FLAG_AB_MAG_>1_SIG   pre=18    post=13    diff=5
# M31_ULX-1                               UVOT_B              FLAG_AB_MAG_99       pre=39    post=6     diff=33
# M31_ULX-1                               UVOT_B              FLAG_UPPER_LIM       pre=6     post=2     diff=4
# M31_ULX-1                               UVOT_B              FLAG_AB_MAG_>10_<30  pre=2     post=2     diff=0
# M31_ULX-1                               UVOT_B              FLAG_AB_MAG_ERR>2    pre=2     post=2     diff=0
# M31_ULX-1                               UVOT_B              FLAG_AB_MAG_>1_SIG   pre=2     post=0     diff=2
# M31_ULX-1                               UVOT_U              FLAG_AB_MAG_99       pre=229   post=100   diff=129
# M31_ULX-1                               UVOT_U              FLAG_UPPER_LIM       pre=100   post=94    diff=6
# M31_ULX-1                               UVOT_U              FLAG_AB_MAG_>10_<30  pre=94    post=94    diff=0
# M31_ULX-1                               UVOT_U              FLAG_AB_MAG_ERR>2    pre=94    post=94    diff=0
# M31_ULX-1                               UVOT_U              FLAG_AB_MAG_>1_SIG   pre=94    post=0     diff=94
# M31_ULX-1                               UVOT_UVM2           FLAG_AB_MAG_99       pre=445   post=206   diff=239
# M31_ULX-1                               UVOT_UVM2           FLAG_UPPER_LIM       pre=206   post=16    diff=190
# M31_ULX-1                               UVOT_UVM2           FLAG_AB_MAG_>10_<30  pre=16    post=16    diff=0
# M31_ULX-1                               UVOT_UVM2           FLAG_AB_MAG_ERR>2    pre=16    post=16    diff=0
# M31_ULX-1                               UVOT_UVM2           FLAG_AB_MAG_>1_SIG   pre=16    post=0     diff=16
# M31_ULX-1                               UVOT_UVW1           FLAG_AB_MAG_99       pre=1385  post=1221  diff=164
# M31_ULX-1                               UVOT_UVW1           FLAG_UPPER_LIM       pre=1221  post=1069  diff=152
# M31_ULX-1                               UVOT_UVW1           FLAG_AB_MAG_>10_<30  pre=1069  post=1069  diff=0
# M31_ULX-1                               UVOT_UVW1           FLAG_AB_MAG_ERR>2    pre=1069  post=1069  diff=0
# M31_ULX-1                               UVOT_UVW1           FLAG_AB_MAG_>1_SIG   pre=1069  post=1069  diff=0
# M31_ULX-1                               UVOT_UVW2           FLAG_AB_MAG_99       pre=542   post=337   diff=205
# M31_ULX-1                               UVOT_UVW2           FLAG_UPPER_LIM       pre=337   post=169   diff=168
# M31_ULX-1                               UVOT_UVW2           FLAG_AB_MAG_>10_<30  pre=169   post=169   diff=0
# M31_ULX-1                               UVOT_UVW2           FLAG_AB_MAG_ERR>2    pre=169   post=169   diff=0
# M31_ULX-1                               UVOT_UVW2           FLAG_AB_MAG_>1_SIG   pre=169   post=169   diff=0
# M31_ULX-1                               UVOT_V              FLAG_AB_MAG_99       pre=36    post=6     diff=30
# M31_ULX-1                               UVOT_V              FLAG_UPPER_LIM       pre=6     post=4     diff=2
# M31_ULX-1                               UVOT_V              FLAG_AB_MAG_>10_<30  pre=4     post=4     diff=0
# M31_ULX-1                               UVOT_V              FLAG_AB_MAG_ERR>2    pre=4     post=4     diff=0
# M31_ULX-1                               UVOT_V              FLAG_AB_MAG_>1_SIG   pre=4     post=0     diff=4
# M31_ULX-1                               UVOT_WHITE          FLAG_AB_MAG_99       pre=19    post=0     diff=19
# M31_ULX-1                               UVOT_WHITE          FLAG_UPPER_LIM       pre=0     post=0     diff=0
# M31_ULX-1                               UVOT_WHITE          FLAG_AB_MAG_>10_<30  pre=0     post=0     diff=0
# M31_ULX-1                               UVOT_WHITE          FLAG_AB_MAG_ERR>2    pre=0     post=0     diff=0
# M31_ULX-1                               UVOT_WHITE          FLAG_AB_MAG_>1_SIG   pre=0     post=0     diff=0
# [LM2005]_NGC_598_ULX1                   XRT_FULL_PC         FLAG_RATE_0          pre=27    post=27    diff=0
# [LM2005]_NGC_598_ULX1                   XRT_FULL_WT         FLAG_RATE_0          pre=1     post=1     diff=0
# [LM2005]_NGC_598_ULX1                   XRT_HARD_PC         FLAG_RATE_0          pre=27    post=27    diff=0
# [LM2005]_NGC_598_ULX1                   XRT_HARD_WT         FLAG_RATE_0          pre=1     post=1     diff=0
# [LM2005]_NGC_598_ULX1                   XRT_HR_PC           FLAG_RATE_0          pre=27    post=27    diff=0
# [LM2005]_NGC_598_ULX1                   XRT_HR_WT           FLAG_RATE_0          pre=1     post=1     diff=0
# [LM2005]_NGC_598_ULX1                   XRT_SOFT_PC         FLAG_RATE_0          pre=27    post=27    diff=0
# [LM2005]_NGC_598_ULX1                   XRT_SOFT_WT         FLAG_RATE_0          pre=1     post=1     diff=0
# [LM2005]_NGC_598_ULX1                   UVOT_B              FLAG_AB_MAG_99       pre=29    post=0     diff=29
# [LM2005]_NGC_598_ULX1                   UVOT_B              FLAG_UPPER_LIM       pre=0     post=0     diff=0
# [LM2005]_NGC_598_ULX1                   UVOT_B              FLAG_AB_MAG_>10_<30  pre=0     post=0     diff=0
# [LM2005]_NGC_598_ULX1                   UVOT_B              FLAG_AB_MAG_ERR>2    pre=0     post=0     diff=0
# [LM2005]_NGC_598_ULX1                   UVOT_B              FLAG_AB_MAG_>1_SIG   pre=0     post=0     diff=0
# [LM2005]_NGC_598_ULX1                   UVOT_U              FLAG_AB_MAG_99       pre=49    post=19    diff=30
# [LM2005]_NGC_598_ULX1                   UVOT_U              FLAG_UPPER_LIM       pre=19    post=19    diff=0
# [LM2005]_NGC_598_ULX1                   UVOT_U              FLAG_AB_MAG_>10_<30  pre=19    post=19    diff=0
# [LM2005]_NGC_598_ULX1                   UVOT_U              FLAG_AB_MAG_ERR>2    pre=19    post=19    diff=0
# [LM2005]_NGC_598_ULX1                   UVOT_U              FLAG_AB_MAG_>1_SIG   pre=19    post=0     diff=19
# [LM2005]_NGC_598_ULX1                   UVOT_UVM2           FLAG_AB_MAG_99       pre=75    post=3     diff=72
# [LM2005]_NGC_598_ULX1                   UVOT_UVM2           FLAG_UPPER_LIM       pre=3     post=3     diff=0
# [LM2005]_NGC_598_ULX1                   UVOT_UVM2           FLAG_AB_MAG_>10_<30  pre=3     post=3     diff=0
# [LM2005]_NGC_598_ULX1                   UVOT_UVM2           FLAG_AB_MAG_ERR>2    pre=3     post=3     diff=0
# [LM2005]_NGC_598_ULX1                   UVOT_UVM2           FLAG_AB_MAG_>1_SIG   pre=3     post=0     diff=3
# [LM2005]_NGC_598_ULX1                   UVOT_UVW1           FLAG_AB_MAG_99       pre=152   post=68    diff=84
# [LM2005]_NGC_598_ULX1                   UVOT_UVW1           FLAG_UPPER_LIM       pre=68    post=9     diff=59
# [LM2005]_NGC_598_ULX1                   UVOT_UVW1           FLAG_AB_MAG_>10_<30  pre=9     post=9     diff=0
# [LM2005]_NGC_598_ULX1                   UVOT_UVW1           FLAG_AB_MAG_ERR>2    pre=9     post=9     diff=0
# [LM2005]_NGC_598_ULX1                   UVOT_UVW1           FLAG_AB_MAG_>1_SIG   pre=9     post=0     diff=9
# [LM2005]_NGC_598_ULX1                   UVOT_UVW2           FLAG_AB_MAG_99       pre=88    post=11    diff=77
# [LM2005]_NGC_598_ULX1                   UVOT_UVW2           FLAG_UPPER_LIM       pre=11    post=7     diff=4
# [LM2005]_NGC_598_ULX1                   UVOT_UVW2           FLAG_AB_MAG_>10_<30  pre=7     post=7     diff=0
# [LM2005]_NGC_598_ULX1                   UVOT_UVW2           FLAG_AB_MAG_ERR>2    pre=7     post=7     diff=0
# [LM2005]_NGC_598_ULX1                   UVOT_UVW2           FLAG_AB_MAG_>1_SIG   pre=7     post=0     diff=7
# [LM2005]_NGC_598_ULX1                   UVOT_V              FLAG_AB_MAG_99       pre=28    post=0     diff=28
# [LM2005]_NGC_598_ULX1                   UVOT_V              FLAG_UPPER_LIM       pre=0     post=0     diff=0
# [LM2005]_NGC_598_ULX1                   UVOT_V              FLAG_AB_MAG_>10_<30  pre=0     post=0     diff=0
# [LM2005]_NGC_598_ULX1                   UVOT_V              FLAG_AB_MAG_ERR>2    pre=0     post=0     diff=0
# [LM2005]_NGC_598_ULX1                   UVOT_V              FLAG_AB_MAG_>1_SIG   pre=0     post=0     diff=0
# RX_J133001+47137                        XRT_FULL_PC         FLAG_RATE_0          pre=168   post=160   diff=8
# RX_J133001+47137                        XRT_HARD_PC         FLAG_RATE_0          pre=108   post=99    diff=9
# RX_J133001+47137                        XRT_HR_PC           FLAG_RATE_0          pre=108   post=98    diff=10
# RX_J133001+47137                        XRT_SOFT_PC         FLAG_RATE_0          pre=108   post=107   diff=1
# RX_J133001+47137                        UVOT_B              FLAG_AB_MAG_99       pre=157   post=146   diff=11
# RX_J133001+47137                        UVOT_B              FLAG_UPPER_LIM       pre=146   post=146   diff=0
# RX_J133001+47137                        UVOT_B              FLAG_AB_MAG_>10_<30  pre=146   post=146   diff=0
# RX_J133001+47137                        UVOT_B              FLAG_AB_MAG_ERR>2    pre=146   post=146   diff=0
# RX_J133001+47137                        UVOT_B              FLAG_AB_MAG_>1_SIG   pre=146   post=146   diff=0
# RX_J133001+47137                        UVOT_U              FLAG_AB_MAG_99       pre=276   post=266   diff=10
# RX_J133001+47137                        UVOT_U              FLAG_UPPER_LIM       pre=266   post=266   diff=0
# RX_J133001+47137                        UVOT_U              FLAG_AB_MAG_>10_<30  pre=266   post=266   diff=0
# RX_J133001+47137                        UVOT_U              FLAG_AB_MAG_ERR>2    pre=266   post=266   diff=0
# RX_J133001+47137                        UVOT_U              FLAG_AB_MAG_>1_SIG   pre=266   post=266   diff=0
# RX_J133001+47137                        UVOT_UVM2           FLAG_AB_MAG_99       pre=225   post=223   diff=2
# RX_J133001+47137                        UVOT_UVM2           FLAG_UPPER_LIM       pre=223   post=223   diff=0
# RX_J133001+47137                        UVOT_UVM2           FLAG_AB_MAG_>10_<30  pre=223   post=223   diff=0
# RX_J133001+47137                        UVOT_UVM2           FLAG_AB_MAG_ERR>2    pre=223   post=223   diff=0
# RX_J133001+47137                        UVOT_UVM2           FLAG_AB_MAG_>1_SIG   pre=223   post=223   diff=0
# RX_J133001+47137                        UVOT_UVW1           FLAG_AB_MAG_99       pre=253   post=247   diff=6
# RX_J133001+47137                        UVOT_UVW1           FLAG_UPPER_LIM       pre=247   post=246   diff=1
# RX_J133001+47137                        UVOT_UVW1           FLAG_AB_MAG_>10_<30  pre=246   post=246   diff=0
# RX_J133001+47137                        UVOT_UVW1           FLAG_AB_MAG_ERR>2    pre=246   post=246   diff=0
# RX_J133001+47137                        UVOT_UVW1           FLAG_AB_MAG_>1_SIG   pre=246   post=246   diff=0
# RX_J133001+47137                        UVOT_UVW2           FLAG_AB_MAG_99       pre=232   post=231   diff=1
# RX_J133001+47137                        UVOT_UVW2           FLAG_UPPER_LIM       pre=231   post=231   diff=0
# RX_J133001+47137                        UVOT_UVW2           FLAG_AB_MAG_>10_<30  pre=231   post=231   diff=0
# RX_J133001+47137                        UVOT_UVW2           FLAG_AB_MAG_ERR>2    pre=231   post=231   diff=0
# RX_J133001+47137                        UVOT_UVW2           FLAG_AB_MAG_>1_SIG   pre=231   post=231   diff=0
# RX_J133001+47137                        UVOT_V              FLAG_AB_MAG_99       pre=160   post=138   diff=22
# RX_J133001+47137                        UVOT_V              FLAG_UPPER_LIM       pre=138   post=138   diff=0
# RX_J133001+47137                        UVOT_V              FLAG_AB_MAG_>10_<30  pre=138   post=138   diff=0
# RX_J133001+47137                        UVOT_V              FLAG_AB_MAG_ERR>2    pre=138   post=138   diff=0
# RX_J133001+47137                        UVOT_V              FLAG_AB_MAG_>1_SIG   pre=138   post=138   diff=0
# RX_J133001+47137                        UVOT_WHITE          FLAG_AB_MAG_99       pre=10    post=0     diff=10
# RX_J133001+47137                        UVOT_WHITE          FLAG_UPPER_LIM       pre=0     post=0     diff=0
# RX_J133001+47137                        UVOT_WHITE          FLAG_AB_MAG_>10_<30  pre=0     post=0     diff=0
# RX_J133001+47137                        UVOT_WHITE          FLAG_AB_MAG_ERR>2    pre=0     post=0     diff=0
# RX_J133001+47137                        UVOT_WHITE          FLAG_AB_MAG_>1_SIG   pre=0     post=0     diff=0
# [LM2005]_NGC_3031_ULX1                  XRT_FULL_PC         FLAG_RATE_0          pre=611   post=608   diff=3
# [LM2005]_NGC_3031_ULX1                  XRT_FULL_WT         FLAG_RATE_0          pre=2     post=1     diff=1
# [LM2005]_NGC_3031_ULX1                  XRT_HARD_PC         FLAG_RATE_0          pre=607   post=604   diff=3
# [LM2005]_NGC_3031_ULX1                  XRT_HR_PC           FLAG_RATE_0          pre=607   post=606   diff=1
# [LM2005]_NGC_3031_ULX1                  XRT_SOFT_PC         FLAG_RATE_0          pre=607   post=603   diff=4
# [LM2005]_NGC_3031_ULX1                  UVOT_B              FLAG_AB_MAG_99       pre=235   post=153   diff=82
# [LM2005]_NGC_3031_ULX1                  UVOT_B              FLAG_UPPER_LIM       pre=153   post=152   diff=1
# [LM2005]_NGC_3031_ULX1                  UVOT_B              FLAG_AB_MAG_>10_<30  pre=152   post=152   diff=0
# [LM2005]_NGC_3031_ULX1                  UVOT_B              FLAG_AB_MAG_ERR>2    pre=152   post=152   diff=0
# [LM2005]_NGC_3031_ULX1                  UVOT_B              FLAG_AB_MAG_>1_SIG   pre=152   post=152   diff=0
# [LM2005]_NGC_3031_ULX1                  UVOT_U              FLAG_AB_MAG_99       pre=352   post=185   diff=167
# [LM2005]_NGC_3031_ULX1                  UVOT_U              FLAG_UPPER_LIM       pre=185   post=180   diff=5
# [LM2005]_NGC_3031_ULX1                  UVOT_U              FLAG_AB_MAG_>10_<30  pre=180   post=180   diff=0
# [LM2005]_NGC_3031_ULX1                  UVOT_U              FLAG_AB_MAG_ERR>2    pre=180   post=180   diff=0
# [LM2005]_NGC_3031_ULX1                  UVOT_U              FLAG_AB_MAG_>1_SIG   pre=180   post=180   diff=0
# [LM2005]_NGC_3031_ULX1                  UVOT_UVM2           FLAG_AB_MAG_99       pre=394   post=193   diff=201
# [LM2005]_NGC_3031_ULX1                  UVOT_UVM2           FLAG_UPPER_LIM       pre=193   post=138   diff=55
# [LM2005]_NGC_3031_ULX1                  UVOT_UVM2           FLAG_AB_MAG_>10_<30  pre=138   post=138   diff=0
# [LM2005]_NGC_3031_ULX1                  UVOT_UVM2           FLAG_AB_MAG_ERR>2    pre=138   post=138   diff=0
# [LM2005]_NGC_3031_ULX1                  UVOT_UVM2           FLAG_AB_MAG_>1_SIG   pre=138   post=0     diff=138
# [LM2005]_NGC_3031_ULX1                  UVOT_UVW1           FLAG_AB_MAG_99       pre=571   post=253   diff=318
# [LM2005]_NGC_3031_ULX1                  UVOT_UVW1           FLAG_UPPER_LIM       pre=253   post=215   diff=38
# [LM2005]_NGC_3031_ULX1                  UVOT_UVW1           FLAG_AB_MAG_>10_<30  pre=215   post=215   diff=0
# [LM2005]_NGC_3031_ULX1                  UVOT_UVW1           FLAG_AB_MAG_ERR>2    pre=215   post=215   diff=0
# [LM2005]_NGC_3031_ULX1                  UVOT_UVW1           FLAG_AB_MAG_>1_SIG   pre=215   post=0     diff=215
# [LM2005]_NGC_3031_ULX1                  UVOT_UVW2           FLAG_AB_MAG_99       pre=941   post=444   diff=497
# [LM2005]_NGC_3031_ULX1                  UVOT_UVW2           FLAG_UPPER_LIM       pre=444   post=365   diff=79
# [LM2005]_NGC_3031_ULX1                  UVOT_UVW2           FLAG_AB_MAG_>10_<30  pre=365   post=365   diff=0
# [LM2005]_NGC_3031_ULX1                  UVOT_UVW2           FLAG_AB_MAG_ERR>2    pre=365   post=365   diff=0
# [LM2005]_NGC_3031_ULX1                  UVOT_UVW2           FLAG_AB_MAG_>1_SIG   pre=365   post=0     diff=365
# [LM2005]_NGC_3031_ULX1                  UVOT_V              FLAG_AB_MAG_99       pre=227   post=152   diff=75
# [LM2005]_NGC_3031_ULX1                  UVOT_V              FLAG_UPPER_LIM       pre=152   post=147   diff=5
# [LM2005]_NGC_3031_ULX1                  UVOT_V              FLAG_AB_MAG_>10_<30  pre=147   post=147   diff=0
# [LM2005]_NGC_3031_ULX1                  UVOT_V              FLAG_AB_MAG_ERR>2    pre=147   post=147   diff=0
# [LM2005]_NGC_3031_ULX1                  UVOT_V              FLAG_AB_MAG_>1_SIG   pre=147   post=147   diff=0
# [LM2005]_NGC_3031_ULX1                  UVOT_WHITE          FLAG_AB_MAG_99       pre=4     post=0     diff=4
# [LM2005]_NGC_3031_ULX1                  UVOT_WHITE          FLAG_UPPER_LIM       pre=0     post=0     diff=0
# [LM2005]_NGC_3031_ULX1                  UVOT_WHITE          FLAG_AB_MAG_>10_<30  pre=0     post=0     diff=0
# [LM2005]_NGC_3031_ULX1                  UVOT_WHITE          FLAG_AB_MAG_ERR>2    pre=0     post=0     diff=0
# [LM2005]_NGC_3031_ULX1                  UVOT_WHITE          FLAG_AB_MAG_>1_SIG   pre=0     post=0     diff=0
# M82_X-2                                 XRT_FULL_PC         FLAG_RATE_0          pre=423   post=415   diff=8
# M82_X-2                                 XRT_FULL_WT         FLAG_RATE_0          pre=9     post=9     diff=0
# M82_X-2                                 XRT_HARD_PC         FLAG_RATE_0          pre=423   post=415   diff=8
# M82_X-2                                 XRT_HARD_WT         FLAG_RATE_0          pre=9     post=9     diff=0
# M82_X-2                                 XRT_HR_PC           FLAG_RATE_0          pre=423   post=423   diff=0
# M82_X-2                                 XRT_HR_WT           FLAG_RATE_0          pre=9     post=9     diff=0
# M82_X-2                                 XRT_SOFT_PC         FLAG_RATE_0          pre=423   post=415   diff=8
# M82_X-2                                 XRT_SOFT_WT         FLAG_RATE_0          pre=9     post=9     diff=0
# M82_X-2                                 UVOT_B              FLAG_AB_MAG_99       pre=100   post=90    diff=10
# M82_X-2                                 UVOT_B              FLAG_UPPER_LIM       pre=90    post=90    diff=0
# M82_X-2                                 UVOT_B              FLAG_AB_MAG_>10_<30  pre=90    post=90    diff=0
# M82_X-2                                 UVOT_B              FLAG_AB_MAG_ERR>2    pre=90    post=90    diff=0
# M82_X-2                                 UVOT_B              FLAG_AB_MAG_>1_SIG   pre=90    post=90    diff=0
# M82_X-2                                 UVOT_U              FLAG_AB_MAG_99       pre=274   post=260   diff=14
# M82_X-2                                 UVOT_U              FLAG_UPPER_LIM       pre=260   post=260   diff=0
# M82_X-2                                 UVOT_U              FLAG_AB_MAG_>10_<30  pre=260   post=260   diff=0
# M82_X-2                                 UVOT_U              FLAG_AB_MAG_ERR>2    pre=260   post=260   diff=0
# M82_X-2                                 UVOT_U              FLAG_AB_MAG_>1_SIG   pre=260   post=260   diff=0
# M82_X-2                                 UVOT_UVM2           FLAG_AB_MAG_99       pre=422   post=399   diff=23
# M82_X-2                                 UVOT_UVM2           FLAG_UPPER_LIM       pre=399   post=393   diff=6
# M82_X-2                                 UVOT_UVM2           FLAG_AB_MAG_>10_<30  pre=393   post=393   diff=0
# M82_X-2                                 UVOT_UVM2           FLAG_AB_MAG_ERR>2    pre=393   post=393   diff=0
# M82_X-2                                 UVOT_UVM2           FLAG_AB_MAG_>1_SIG   pre=393   post=393   diff=0
# M82_X-2                                 UVOT_UVW1           FLAG_AB_MAG_99       pre=364   post=340   diff=24
# M82_X-2                                 UVOT_UVW1           FLAG_UPPER_LIM       pre=340   post=340   diff=0
# M82_X-2                                 UVOT_UVW1           FLAG_AB_MAG_>10_<30  pre=340   post=340   diff=0
# M82_X-2                                 UVOT_UVW1           FLAG_AB_MAG_ERR>2    pre=340   post=340   diff=0
# M82_X-2                                 UVOT_UVW1           FLAG_AB_MAG_>1_SIG   pre=340   post=340   diff=0
# M82_X-2                                 UVOT_UVW2           FLAG_AB_MAG_99       pre=358   post=338   diff=20
# M82_X-2                                 UVOT_UVW2           FLAG_UPPER_LIM       pre=338   post=338   diff=0
# M82_X-2                                 UVOT_UVW2           FLAG_AB_MAG_>10_<30  pre=338   post=338   diff=0
# M82_X-2                                 UVOT_UVW2           FLAG_AB_MAG_ERR>2    pre=338   post=338   diff=0
# M82_X-2                                 UVOT_UVW2           FLAG_AB_MAG_>1_SIG   pre=338   post=338   diff=0
# M82_X-2                                 UVOT_V              FLAG_AB_MAG_99       pre=92    post=86    diff=6
# M82_X-2                                 UVOT_V              FLAG_UPPER_LIM       pre=86    post=86    diff=0
# M82_X-2                                 UVOT_V              FLAG_AB_MAG_>10_<30  pre=86    post=86    diff=0
# M82_X-2                                 UVOT_V              FLAG_AB_MAG_ERR>2    pre=86    post=86    diff=0
# M82_X-2                                 UVOT_V              FLAG_AB_MAG_>1_SIG   pre=86    post=86    diff=0
# M82_X-2                                 UVOT_WHITE          FLAG_AB_MAG_99       pre=31    post=0     diff=31
# M82_X-2                                 UVOT_WHITE          FLAG_UPPER_LIM       pre=0     post=0     diff=0
# M82_X-2                                 UVOT_WHITE          FLAG_AB_MAG_>10_<30  pre=0     post=0     diff=0
# M82_X-2                                 UVOT_WHITE          FLAG_AB_MAG_ERR>2    pre=0     post=0     diff=0
# M82_X-2                                 UVOT_WHITE          FLAG_AB_MAG_>1_SIG   pre=0     post=0     diff=0
# [LM2005]_NGC_1042_ULX1                  XRT_FULL_PC         FLAG_RATE_0          pre=8     post=8     diff=0
# [LM2005]_NGC_1042_ULX1                  XRT_HARD_PC         FLAG_RATE_0          pre=8     post=8     diff=0
# [LM2005]_NGC_1042_ULX1                  XRT_HR_PC           FLAG_RATE_0          pre=8     post=8     diff=0
# [LM2005]_NGC_1042_ULX1                  XRT_SOFT_PC         FLAG_RATE_0          pre=8     post=8     diff=0
# [LM2005]_NGC_1042_ULX1                  UVOT_B              FLAG_AB_MAG_99       pre=62    post=7     diff=55
# [LM2005]_NGC_1042_ULX1                  UVOT_B              FLAG_UPPER_LIM       pre=7     post=4     diff=3
# [LM2005]_NGC_1042_ULX1                  UVOT_B              FLAG_AB_MAG_>10_<30  pre=4     post=4     diff=0
# [LM2005]_NGC_1042_ULX1                  UVOT_B              FLAG_AB_MAG_ERR>2    pre=4     post=4     diff=0
# [LM2005]_NGC_1042_ULX1                  UVOT_B              FLAG_AB_MAG_>1_SIG   pre=4     post=0     diff=4
# [LM2005]_NGC_1042_ULX1                  UVOT_U              FLAG_AB_MAG_99       pre=89    post=14    diff=75
# [LM2005]_NGC_1042_ULX1                  UVOT_U              FLAG_UPPER_LIM       pre=14    post=10    diff=4
# [LM2005]_NGC_1042_ULX1                  UVOT_U              FLAG_AB_MAG_>10_<30  pre=10    post=10    diff=0
# [LM2005]_NGC_1042_ULX1                  UVOT_U              FLAG_AB_MAG_ERR>2    pre=10    post=10    diff=0
# [LM2005]_NGC_1042_ULX1                  UVOT_U              FLAG_AB_MAG_>1_SIG   pre=10    post=0     diff=10
# [LM2005]_NGC_1042_ULX1                  UVOT_UVM2           FLAG_AB_MAG_99       pre=88    post=9     diff=79
# [LM2005]_NGC_1042_ULX1                  UVOT_UVM2           FLAG_UPPER_LIM       pre=9     post=8     diff=1
# [LM2005]_NGC_1042_ULX1                  UVOT_UVM2           FLAG_AB_MAG_>10_<30  pre=8     post=8     diff=0
# [LM2005]_NGC_1042_ULX1                  UVOT_UVM2           FLAG_AB_MAG_ERR>2    pre=8     post=8     diff=0
# [LM2005]_NGC_1042_ULX1                  UVOT_UVM2           FLAG_AB_MAG_>1_SIG   pre=8     post=0     diff=8
# [LM2005]_NGC_1042_ULX1                  UVOT_UVW1           FLAG_AB_MAG_99       pre=83    post=9     diff=74
# [LM2005]_NGC_1042_ULX1                  UVOT_UVW1           FLAG_UPPER_LIM       pre=9     post=7     diff=2
# [LM2005]_NGC_1042_ULX1                  UVOT_UVW1           FLAG_AB_MAG_>10_<30  pre=7     post=7     diff=0
# [LM2005]_NGC_1042_ULX1                  UVOT_UVW1           FLAG_AB_MAG_ERR>2    pre=7     post=7     diff=0
# [LM2005]_NGC_1042_ULX1                  UVOT_UVW1           FLAG_AB_MAG_>1_SIG   pre=7     post=0     diff=7
# [LM2005]_NGC_1042_ULX1                  UVOT_UVW2           FLAG_AB_MAG_99       pre=88    post=11    diff=77
# [LM2005]_NGC_1042_ULX1                  UVOT_UVW2           FLAG_UPPER_LIM       pre=11    post=11    diff=0
# [LM2005]_NGC_1042_ULX1                  UVOT_UVW2           FLAG_AB_MAG_>10_<30  pre=11    post=11    diff=0
# [LM2005]_NGC_1042_ULX1                  UVOT_UVW2           FLAG_AB_MAG_ERR>2    pre=11    post=11    diff=0
# [LM2005]_NGC_1042_ULX1                  UVOT_UVW2           FLAG_AB_MAG_>1_SIG   pre=11    post=0     diff=11
# [LM2005]_NGC_1042_ULX1                  UVOT_V              FLAG_AB_MAG_99       pre=59    post=7     diff=52
# [LM2005]_NGC_1042_ULX1                  UVOT_V              FLAG_UPPER_LIM       pre=7     post=4     diff=3
# [LM2005]_NGC_1042_ULX1                  UVOT_V              FLAG_AB_MAG_>10_<30  pre=4     post=4     diff=0
# [LM2005]_NGC_1042_ULX1                  UVOT_V              FLAG_AB_MAG_ERR>2    pre=4     post=4     diff=0
# [LM2005]_NGC_1042_ULX1                  UVOT_V              FLAG_AB_MAG_>1_SIG   pre=4     post=0     diff=4
# NAME_NGC_1313_X-1                       XRT_FULL_PC         FLAG_RATE_0          pre=498   post=497   diff=1
# NAME_NGC_1313_X-1                       XRT_HARD_PC         FLAG_RATE_0          pre=498   post=497   diff=1
# NAME_NGC_1313_X-1                       XRT_HR_PC           FLAG_RATE_0          pre=498   post=498   diff=0
# NAME_NGC_1313_X-1                       XRT_SOFT_PC         FLAG_RATE_0          pre=498   post=497   diff=1
# NAME_NGC_1313_X-1                       UVOT_B              FLAG_AB_MAG_99       pre=19    post=19    diff=0
# NAME_NGC_1313_X-1                       UVOT_B              FLAG_UPPER_LIM       pre=19    post=19    diff=0
# NAME_NGC_1313_X-1                       UVOT_B              FLAG_AB_MAG_>10_<30  pre=19    post=19    diff=0
# NAME_NGC_1313_X-1                       UVOT_B              FLAG_AB_MAG_ERR>2    pre=19    post=19    diff=0
# NAME_NGC_1313_X-1                       UVOT_B              FLAG_AB_MAG_>1_SIG   pre=19    post=11    diff=8
# NAME_NGC_1313_X-1                       UVOT_U              FLAG_AB_MAG_99       pre=474   post=470   diff=4
# NAME_NGC_1313_X-1                       UVOT_U              FLAG_UPPER_LIM       pre=470   post=470   diff=0
# NAME_NGC_1313_X-1                       UVOT_U              FLAG_AB_MAG_>10_<30  pre=470   post=470   diff=0
# NAME_NGC_1313_X-1                       UVOT_U              FLAG_AB_MAG_ERR>2    pre=470   post=470   diff=0
# NAME_NGC_1313_X-1                       UVOT_U              FLAG_AB_MAG_>1_SIG   pre=470   post=470   diff=0
# NAME_NGC_1313_X-1                       UVOT_UVM2           FLAG_AB_MAG_99       pre=169   post=168   diff=1
# NAME_NGC_1313_X-1                       UVOT_UVM2           FLAG_UPPER_LIM       pre=168   post=167   diff=1
# NAME_NGC_1313_X-1                       UVOT_UVM2           FLAG_AB_MAG_>10_<30  pre=167   post=167   diff=0
# NAME_NGC_1313_X-1                       UVOT_UVM2           FLAG_AB_MAG_ERR>2    pre=167   post=167   diff=0
# NAME_NGC_1313_X-1                       UVOT_UVM2           FLAG_AB_MAG_>1_SIG   pre=167   post=167   diff=0
# NAME_NGC_1313_X-1                       UVOT_UVW1           FLAG_AB_MAG_99       pre=91    post=91    diff=0
# NAME_NGC_1313_X-1                       UVOT_UVW1           FLAG_UPPER_LIM       pre=91    post=91    diff=0
# NAME_NGC_1313_X-1                       UVOT_UVW1           FLAG_AB_MAG_>10_<30  pre=91    post=91    diff=0
# NAME_NGC_1313_X-1                       UVOT_UVW1           FLAG_AB_MAG_ERR>2    pre=91    post=91    diff=0
# NAME_NGC_1313_X-1                       UVOT_UVW1           FLAG_AB_MAG_>1_SIG   pre=91    post=59    diff=32
# NAME_NGC_1313_X-1                       UVOT_UVW2           FLAG_AB_MAG_99       pre=124   post=123   diff=1
# NAME_NGC_1313_X-1                       UVOT_UVW2           FLAG_UPPER_LIM       pre=123   post=123   diff=0
# NAME_NGC_1313_X-1                       UVOT_UVW2           FLAG_AB_MAG_>10_<30  pre=123   post=123   diff=0
# NAME_NGC_1313_X-1                       UVOT_UVW2           FLAG_AB_MAG_ERR>2    pre=123   post=123   diff=0
# NAME_NGC_1313_X-1                       UVOT_UVW2           FLAG_AB_MAG_>1_SIG   pre=123   post=123   diff=0
# NAME_NGC_1313_X-1                       UVOT_V              FLAG_AB_MAG_99       pre=17    post=17    diff=0
# NAME_NGC_1313_X-1                       UVOT_V              FLAG_UPPER_LIM       pre=17    post=17    diff=0
# NAME_NGC_1313_X-1                       UVOT_V              FLAG_AB_MAG_>10_<30  pre=17    post=17    diff=0
# NAME_NGC_1313_X-1                       UVOT_V              FLAG_AB_MAG_ERR>2    pre=17    post=17    diff=0
# NAME_NGC_1313_X-1                       UVOT_V              FLAG_AB_MAG_>1_SIG   pre=17    post=14    diff=3
# NAME_NGC_1313_X-2                       XRT_FULL_PC         FLAG_RATE_0          pre=452   post=451   diff=1
# NAME_NGC_1313_X-2                       XRT_HARD_PC         FLAG_RATE_0          pre=452   post=451   diff=1
# NAME_NGC_1313_X-2                       XRT_HR_PC           FLAG_RATE_0          pre=452   post=452   diff=0
# NAME_NGC_1313_X-2                       XRT_SOFT_PC         FLAG_RATE_0          pre=452   post=451   diff=1
# NAME_NGC_1313_X-2                       UVOT_B              FLAG_AB_MAG_99       pre=19    post=19    diff=0
# NAME_NGC_1313_X-2                       UVOT_B              FLAG_UPPER_LIM       pre=19    post=4     diff=15
# NAME_NGC_1313_X-2                       UVOT_B              FLAG_AB_MAG_>10_<30  pre=4     post=4     diff=0
# NAME_NGC_1313_X-2                       UVOT_B              FLAG_AB_MAG_ERR>2    pre=4     post=4     diff=0
# NAME_NGC_1313_X-2                       UVOT_B              FLAG_AB_MAG_>1_SIG   pre=4     post=2     diff=2
# NAME_NGC_1313_X-2                       UVOT_U              FLAG_AB_MAG_99       pre=474   post=456   diff=18
# NAME_NGC_1313_X-2                       UVOT_U              FLAG_UPPER_LIM       pre=456   post=430   diff=26
# NAME_NGC_1313_X-2                       UVOT_U              FLAG_AB_MAG_>10_<30  pre=430   post=430   diff=0
# NAME_NGC_1313_X-2                       UVOT_U              FLAG_AB_MAG_ERR>2    pre=430   post=430   diff=0
# NAME_NGC_1313_X-2                       UVOT_U              FLAG_AB_MAG_>1_SIG   pre=430   post=430   diff=0
# NAME_NGC_1313_X-2                       UVOT_UVM2           FLAG_AB_MAG_99       pre=169   post=169   diff=0
# NAME_NGC_1313_X-2                       UVOT_UVM2           FLAG_UPPER_LIM       pre=169   post=158   diff=11
# NAME_NGC_1313_X-2                       UVOT_UVM2           FLAG_AB_MAG_>10_<30  pre=158   post=158   diff=0
# NAME_NGC_1313_X-2                       UVOT_UVM2           FLAG_AB_MAG_ERR>2    pre=158   post=158   diff=0
# NAME_NGC_1313_X-2                       UVOT_UVM2           FLAG_AB_MAG_>1_SIG   pre=158   post=133   diff=25
# NAME_NGC_1313_X-2                       UVOT_UVW1           FLAG_AB_MAG_99       pre=91    post=91    diff=0
# NAME_NGC_1313_X-2                       UVOT_UVW1           FLAG_UPPER_LIM       pre=91    post=88    diff=3
# NAME_NGC_1313_X-2                       UVOT_UVW1           FLAG_AB_MAG_>10_<30  pre=88    post=88    diff=0
# NAME_NGC_1313_X-2                       UVOT_UVW1           FLAG_AB_MAG_ERR>2    pre=88    post=88    diff=0
# NAME_NGC_1313_X-2                       UVOT_UVW1           FLAG_AB_MAG_>1_SIG   pre=88    post=65    diff=23
# NAME_NGC_1313_X-2                       UVOT_UVW2           FLAG_AB_MAG_99       pre=124   post=124   diff=0
# NAME_NGC_1313_X-2                       UVOT_UVW2           FLAG_UPPER_LIM       pre=124   post=122   diff=2
# NAME_NGC_1313_X-2                       UVOT_UVW2           FLAG_AB_MAG_>10_<30  pre=122   post=122   diff=0
# NAME_NGC_1313_X-2                       UVOT_UVW2           FLAG_AB_MAG_ERR>2    pre=122   post=122   diff=0
# NAME_NGC_1313_X-2                       UVOT_UVW2           FLAG_AB_MAG_>1_SIG   pre=122   post=85    diff=37
# NAME_NGC_1313_X-2                       UVOT_V              FLAG_AB_MAG_99       pre=17    post=16    diff=1
# NAME_NGC_1313_X-2                       UVOT_V              FLAG_UPPER_LIM       pre=16    post=0     diff=16
# NAME_NGC_1313_X-2                       UVOT_V              FLAG_AB_MAG_>10_<30  pre=0     post=0     diff=0
# NAME_NGC_1313_X-2                       UVOT_V              FLAG_AB_MAG_ERR>2    pre=0     post=0     diff=0
# NAME_NGC_1313_X-2                       UVOT_V              FLAG_AB_MAG_>1_SIG   pre=0     post=0     diff=0
# [LM2005]_NGC_247_ULX1                   XRT_FULL_PC         FLAG_RATE_0          pre=117   post=117   diff=0
# [LM2005]_NGC_247_ULX1                   XRT_HARD_PC         FLAG_RATE_0          pre=117   post=90    diff=27
# [LM2005]_NGC_247_ULX1                   XRT_HR_PC           FLAG_RATE_0          pre=117   post=90    diff=27
# [LM2005]_NGC_247_ULX1                   XRT_SOFT_PC         FLAG_RATE_0          pre=117   post=117   diff=0
# [LM2005]_NGC_247_ULX1                   UVOT_B              FLAG_AB_MAG_99       pre=3     post=3     diff=0
# [LM2005]_NGC_247_ULX1                   UVOT_B              FLAG_UPPER_LIM       pre=3     post=3     diff=0
# [LM2005]_NGC_247_ULX1                   UVOT_B              FLAG_AB_MAG_>10_<30  pre=3     post=3     diff=0
# [LM2005]_NGC_247_ULX1                   UVOT_B              FLAG_AB_MAG_ERR>2    pre=3     post=3     diff=0
# [LM2005]_NGC_247_ULX1                   UVOT_B              FLAG_AB_MAG_>1_SIG   pre=3     post=2     diff=1
# [LM2005]_NGC_247_ULX1                   UVOT_U              FLAG_AB_MAG_99       pre=42    post=42    diff=0
# [LM2005]_NGC_247_ULX1                   UVOT_U              FLAG_UPPER_LIM       pre=42    post=41    diff=1
# [LM2005]_NGC_247_ULX1                   UVOT_U              FLAG_AB_MAG_>10_<30  pre=41    post=41    diff=0
# [LM2005]_NGC_247_ULX1                   UVOT_U              FLAG_AB_MAG_ERR>2    pre=41    post=41    diff=0
# [LM2005]_NGC_247_ULX1                   UVOT_U              FLAG_AB_MAG_>1_SIG   pre=41    post=27    diff=14
# [LM2005]_NGC_247_ULX1                   UVOT_UVM2           FLAG_AB_MAG_99       pre=135   post=135   diff=0
# [LM2005]_NGC_247_ULX1                   UVOT_UVM2           FLAG_UPPER_LIM       pre=135   post=135   diff=0
# [LM2005]_NGC_247_ULX1                   UVOT_UVM2           FLAG_AB_MAG_>10_<30  pre=135   post=135   diff=0
# [LM2005]_NGC_247_ULX1                   UVOT_UVM2           FLAG_AB_MAG_ERR>2    pre=135   post=135   diff=0
# [LM2005]_NGC_247_ULX1                   UVOT_UVM2           FLAG_AB_MAG_>1_SIG   pre=135   post=98    diff=37
# ...
# [SK2009]_X2                             UVOT_V              FLAG_AB_MAG_>1_SIG   pre=118   post=102   diff=16
# [SK2009]_X2                             UVOT_WHITE          FLAG_AB_MAG_99       pre=12    post=12    diff=0
# [SK2009]_X2                             UVOT_WHITE          FLAG_UPPER_LIM       pre=12    post=12    diff=0
# [SK2009]_X2                             UVOT_WHITE          FLAG_AB_MAG_>10_<30  pre=12    post=12    diff=0
# [SK2009]_X2                             UVOT_WHITE          FLAG_AB_MAG_ERR>2    pre=12    post=12    diff=0
# [SK2009]_X2                             UVOT_WHITE          FLAG_AB_MAG_>1_SIG   pre=12    post=10    diff=2
# NAME_IC_10_X-1                          XRT_FULL_PC         FLAG_RATE_0          pre=103   post=102   diff=1
# NAME_IC_10_X-1                          XRT_HARD_PC         FLAG_RATE_0          pre=103   post=102   diff=1
# NAME_IC_10_X-1                          XRT_HR_PC           FLAG_RATE_0          pre=103   post=103   diff=0
# NAME_IC_10_X-1                          XRT_SOFT_PC         FLAG_RATE_0          pre=103   post=102   diff=1
# NAME_IC_10_X-1                          UVOT_U              FLAG_AB_MAG_99       pre=253   post=251   diff=2
# NAME_IC_10_X-1                          UVOT_U              FLAG_UPPER_LIM       pre=251   post=232   diff=19
# NAME_IC_10_X-1                          UVOT_U              FLAG_AB_MAG_>10_<30  pre=232   post=232   diff=0
# NAME_IC_10_X-1                          UVOT_U              FLAG_AB_MAG_ERR>2    pre=232   post=232   diff=0
# NAME_IC_10_X-1                          UVOT_U              FLAG_AB_MAG_>1_SIG   pre=232   post=232   diff=0
# NAME_IC_10_X-1                          UVOT_UVM2           FLAG_AB_MAG_99       pre=35    post=25    diff=10
# NAME_IC_10_X-1                          UVOT_UVM2           FLAG_UPPER_LIM       pre=25    post=0     diff=25
# NAME_IC_10_X-1                          UVOT_UVM2           FLAG_AB_MAG_>10_<30  pre=0     post=0     diff=0
# NAME_IC_10_X-1                          UVOT_UVM2           FLAG_AB_MAG_ERR>2    pre=0     post=0     diff=0
# NAME_IC_10_X-1                          UVOT_UVM2           FLAG_AB_MAG_>1_SIG   pre=0     post=0     diff=0
# NAME_IC_10_X-1                          UVOT_UVW1           FLAG_AB_MAG_99       pre=25    post=25    diff=0
# NAME_IC_10_X-1                          UVOT_UVW1           FLAG_UPPER_LIM       pre=25    post=18    diff=7
# NAME_IC_10_X-1                          UVOT_UVW1           FLAG_AB_MAG_>10_<30  pre=18    post=18    diff=0
# NAME_IC_10_X-1                          UVOT_UVW1           FLAG_AB_MAG_ERR>2    pre=18    post=18    diff=0
# NAME_IC_10_X-1                          UVOT_UVW1           FLAG_AB_MAG_>1_SIG   pre=18    post=14    diff=4
# NAME_IC_10_X-1                          UVOT_UVW2           FLAG_AB_MAG_99       pre=37    post=29    diff=8
# NAME_IC_10_X-1                          UVOT_UVW2           FLAG_UPPER_LIM       pre=29    post=2     diff=27
# NAME_IC_10_X-1                          UVOT_UVW2           FLAG_AB_MAG_>10_<30  pre=2     post=2     diff=0
# NAME_IC_10_X-1                          UVOT_UVW2           FLAG_AB_MAG_ERR>2    pre=2     post=2     diff=0
# NAME_IC_10_X-1                          UVOT_UVW2           FLAG_AB_MAG_>1_SIG   pre=2     post=2     diff=0
# [WMR2006]_NGC4945_XMM1                  XRT_FULL_PC         FLAG_RATE_0          pre=50    post=50    diff=0
# [WMR2006]_NGC4945_XMM1                  XRT_HARD_PC         FLAG_RATE_0          pre=50    post=50    diff=0
# [WMR2006]_NGC4945_XMM1                  XRT_HR_PC           FLAG_RATE_0          pre=50    post=49    diff=1
# [WMR2006]_NGC4945_XMM1                  XRT_SOFT_PC         FLAG_RATE_0          pre=50    post=49    diff=1
# [WMR2006]_NGC4945_XMM1                  UVOT_B              FLAG_AB_MAG_99       pre=10    post=10    diff=0
# [WMR2006]_NGC4945_XMM1                  UVOT_B              FLAG_UPPER_LIM       pre=10    post=10    diff=0
# [WMR2006]_NGC4945_XMM1                  UVOT_B              FLAG_AB_MAG_>10_<30  pre=10    post=10    diff=0
# [WMR2006]_NGC4945_XMM1                  UVOT_B              FLAG_AB_MAG_ERR>2    pre=10    post=10    diff=0
# [WMR2006]_NGC4945_XMM1                  UVOT_B              FLAG_AB_MAG_>1_SIG   pre=10    post=6     diff=4
# [WMR2006]_NGC4945_XMM1                  UVOT_U              FLAG_AB_MAG_99       pre=10    post=10    diff=0
# [WMR2006]_NGC4945_XMM1                  UVOT_U              FLAG_UPPER_LIM       pre=10    post=10    diff=0
# [WMR2006]_NGC4945_XMM1                  UVOT_U              FLAG_AB_MAG_>10_<30  pre=10    post=10    diff=0
# [WMR2006]_NGC4945_XMM1                  UVOT_U              FLAG_AB_MAG_ERR>2    pre=10    post=10    diff=0
# [WMR2006]_NGC4945_XMM1                  UVOT_U              FLAG_AB_MAG_>1_SIG   pre=10    post=6     diff=4
# [WMR2006]_NGC4945_XMM1                  UVOT_UVM2           FLAG_AB_MAG_99       pre=71    post=69    diff=2
# [WMR2006]_NGC4945_XMM1                  UVOT_UVM2           FLAG_UPPER_LIM       pre=69    post=51    diff=18
# [WMR2006]_NGC4945_XMM1                  UVOT_UVM2           FLAG_AB_MAG_>10_<30  pre=51    post=51    diff=0
# [WMR2006]_NGC4945_XMM1                  UVOT_UVM2           FLAG_AB_MAG_ERR>2    pre=51    post=51    diff=0
# [WMR2006]_NGC4945_XMM1                  UVOT_UVM2           FLAG_AB_MAG_>1_SIG   pre=51    post=51    diff=0
# [WMR2006]_NGC4945_XMM1                  UVOT_UVW1           FLAG_AB_MAG_99       pre=55    post=54    diff=1
# [WMR2006]_NGC4945_XMM1                  UVOT_UVW1           FLAG_UPPER_LIM       pre=54    post=52    diff=2
# [WMR2006]_NGC4945_XMM1                  UVOT_UVW1           FLAG_AB_MAG_>10_<30  pre=52    post=52    diff=0
# [WMR2006]_NGC4945_XMM1                  UVOT_UVW1           FLAG_AB_MAG_ERR>2    pre=52    post=52    diff=0
# [WMR2006]_NGC4945_XMM1                  UVOT_UVW1           FLAG_AB_MAG_>1_SIG   pre=52    post=52    diff=0
# [WMR2006]_NGC4945_XMM1                  UVOT_UVW2           FLAG_AB_MAG_99       pre=76    post=76    diff=0
# [WMR2006]_NGC4945_XMM1                  UVOT_UVW2           FLAG_UPPER_LIM       pre=76    post=68    diff=8
# [WMR2006]_NGC4945_XMM1                  UVOT_UVW2           FLAG_AB_MAG_>10_<30  pre=68    post=68    diff=0
# [WMR2006]_NGC4945_XMM1                  UVOT_UVW2           FLAG_AB_MAG_ERR>2    pre=68    post=68    diff=0
# [WMR2006]_NGC4945_XMM1                  UVOT_UVW2           FLAG_AB_MAG_>1_SIG   pre=68    post=50    diff=18
# [WMR2006]_NGC4945_XMM1                  UVOT_V              FLAG_AB_MAG_99       pre=9     post=9     diff=0
# [WMR2006]_NGC4945_XMM1                  UVOT_V              FLAG_UPPER_LIM       pre=9     post=9     diff=0
# [WMR2006]_NGC4945_XMM1                  UVOT_V              FLAG_AB_MAG_>10_<30  pre=9     post=9     diff=0
# [WMR2006]_NGC4945_XMM1                  UVOT_V              FLAG_AB_MAG_ERR>2    pre=9     post=9     diff=0
# [WMR2006]_NGC4945_XMM1                  UVOT_V              FLAG_AB_MAG_>1_SIG   pre=9     post=6     diff=3
# [LB2005]_NGC_3031_X6                    XRT_FULL_PC         FLAG_RATE_0          pre=19    post=19    diff=0
# [LB2005]_NGC_3031_X6                    XRT_FULL_WT         FLAG_RATE_0          pre=1     post=1     diff=0
# [LB2005]_NGC_3031_X6                    XRT_HARD_PC         FLAG_RATE_0          pre=19    post=19    diff=0
# [LB2005]_NGC_3031_X6                    XRT_HARD_WT         FLAG_RATE_0          pre=1     post=1     diff=0
# [LB2005]_NGC_3031_X6                    XRT_HR_PC           FLAG_RATE_0          pre=19    post=17    diff=2
# [LB2005]_NGC_3031_X6                    XRT_HR_WT           FLAG_RATE_0          pre=1     post=1     diff=0
# [LB2005]_NGC_3031_X6                    XRT_SOFT_PC         FLAG_RATE_0          pre=19    post=17    diff=2
# [LB2005]_NGC_3031_X6                    XRT_SOFT_WT         FLAG_RATE_0          pre=1     post=1     diff=0
# [LB2005]_NGC_3031_X6                    UVOT_B              FLAG_AB_MAG_99       pre=235   post=153   diff=82
# [LB2005]_NGC_3031_X6                    UVOT_B              FLAG_UPPER_LIM       pre=153   post=152   diff=1
# [LB2005]_NGC_3031_X6                    UVOT_B              FLAG_AB_MAG_>10_<30  pre=152   post=152   diff=0
# [LB2005]_NGC_3031_X6                    UVOT_B              FLAG_AB_MAG_ERR>2    pre=152   post=152   diff=0
# [LB2005]_NGC_3031_X6                    UVOT_B              FLAG_AB_MAG_>1_SIG   pre=152   post=152   diff=0
# [LB2005]_NGC_3031_X6                    UVOT_U              FLAG_AB_MAG_99       pre=352   post=185   diff=167
# [LB2005]_NGC_3031_X6                    UVOT_U              FLAG_UPPER_LIM       pre=185   post=180   diff=5
# [LB2005]_NGC_3031_X6                    UVOT_U              FLAG_AB_MAG_>10_<30  pre=180   post=180   diff=0
# [LB2005]_NGC_3031_X6                    UVOT_U              FLAG_AB_MAG_ERR>2    pre=180   post=180   diff=0
# [LB2005]_NGC_3031_X6                    UVOT_U              FLAG_AB_MAG_>1_SIG   pre=180   post=180   diff=0
# [LB2005]_NGC_3031_X6                    UVOT_UVM2           FLAG_AB_MAG_99       pre=394   post=193   diff=201
# [LB2005]_NGC_3031_X6                    UVOT_UVM2           FLAG_UPPER_LIM       pre=193   post=138   diff=55
# [LB2005]_NGC_3031_X6                    UVOT_UVM2           FLAG_AB_MAG_>10_<30  pre=138   post=138   diff=0
# [LB2005]_NGC_3031_X6                    UVOT_UVM2           FLAG_AB_MAG_ERR>2    pre=138   post=138   diff=0
# [LB2005]_NGC_3031_X6                    UVOT_UVM2           FLAG_AB_MAG_>1_SIG   pre=138   post=0     diff=138
# [LB2005]_NGC_3031_X6                    UVOT_UVW1           FLAG_AB_MAG_99       pre=571   post=253   diff=318
# [LB2005]_NGC_3031_X6                    UVOT_UVW1           FLAG_UPPER_LIM       pre=253   post=215   diff=38
# [LB2005]_NGC_3031_X6                    UVOT_UVW1           FLAG_AB_MAG_>10_<30  pre=215   post=215   diff=0
# [LB2005]_NGC_3031_X6                    UVOT_UVW1           FLAG_AB_MAG_ERR>2    pre=215   post=215   diff=0
# [LB2005]_NGC_3031_X6                    UVOT_UVW1           FLAG_AB_MAG_>1_SIG   pre=215   post=0     diff=215
# [LB2005]_NGC_3031_X6                    UVOT_UVW2           FLAG_AB_MAG_99       pre=941   post=444   diff=497
# [LB2005]_NGC_3031_X6                    UVOT_UVW2           FLAG_UPPER_LIM       pre=444   post=365   diff=79
# [LB2005]_NGC_3031_X6                    UVOT_UVW2           FLAG_AB_MAG_>10_<30  pre=365   post=365   diff=0
# [LB2005]_NGC_3031_X6                    UVOT_UVW2           FLAG_AB_MAG_ERR>2    pre=365   post=365   diff=0
# [LB2005]_NGC_3031_X6                    UVOT_UVW2           FLAG_AB_MAG_>1_SIG   pre=365   post=0     diff=365
# [LB2005]_NGC_3031_X6                    UVOT_V              FLAG_AB_MAG_99       pre=227   post=152   diff=75
# [LB2005]_NGC_3031_X6                    UVOT_V              FLAG_UPPER_LIM       pre=152   post=147   diff=5
# [LB2005]_NGC_3031_X6                    UVOT_V              FLAG_AB_MAG_>10_<30  pre=147   post=147   diff=0
# [LB2005]_NGC_3031_X6                    UVOT_V              FLAG_AB_MAG_ERR>2    pre=147   post=147   diff=0
# [LB2005]_NGC_3031_X6                    UVOT_V              FLAG_AB_MAG_>1_SIG   pre=147   post=147   diff=0
# [LB2005]_NGC_3031_X6                    UVOT_WHITE          FLAG_AB_MAG_99       pre=4     post=0     diff=4
# [LB2005]_NGC_3031_X6                    UVOT_WHITE          FLAG_UPPER_LIM       pre=0     post=0     diff=0
# [LB2005]_NGC_3031_X6                    UVOT_WHITE          FLAG_AB_MAG_>10_<30  pre=0     post=0     diff=0
# [LB2005]_NGC_3031_X6                    UVOT_WHITE          FLAG_AB_MAG_ERR>2    pre=0     post=0     diff=0
# [LB2005]_NGC_3031_X6                    UVOT_WHITE          FLAG_AB_MAG_>1_SIG   pre=0     post=0     diff=0
# [LM2005]_NGC_4559_ULX1                  XRT_FULL_PC         FLAG_RATE_0          pre=89    post=89    diff=0
# [LM2005]_NGC_4559_ULX1                  XRT_HARD_PC         FLAG_RATE_0          pre=89    post=89    diff=0
# [LM2005]_NGC_4559_ULX1                  XRT_HR_PC           FLAG_RATE_0          pre=89    post=89    diff=0
# [LM2005]_NGC_4559_ULX1                  XRT_SOFT_PC         FLAG_RATE_0          pre=89    post=89    diff=0
# [LM2005]_NGC_4559_ULX1                  UVOT_B              FLAG_AB_MAG_99       pre=31    post=31    diff=0
# [LM2005]_NGC_4559_ULX1                  UVOT_B              FLAG_UPPER_LIM       pre=31    post=30    diff=1
# [LM2005]_NGC_4559_ULX1                  UVOT_B              FLAG_AB_MAG_>10_<30  pre=30    post=30    diff=0
# [LM2005]_NGC_4559_ULX1                  UVOT_B              FLAG_AB_MAG_ERR>2    pre=30    post=30    diff=0
# [LM2005]_NGC_4559_ULX1                  UVOT_B              FLAG_AB_MAG_>1_SIG   pre=30    post=23    diff=7
# [LM2005]_NGC_4559_ULX1                  UVOT_U              FLAG_AB_MAG_99       pre=54    post=54    diff=0
# [LM2005]_NGC_4559_ULX1                  UVOT_U              FLAG_UPPER_LIM       pre=54    post=54    diff=0
# [LM2005]_NGC_4559_ULX1                  UVOT_U              FLAG_AB_MAG_>10_<30  pre=54    post=54    diff=0
# [LM2005]_NGC_4559_ULX1                  UVOT_U              FLAG_AB_MAG_ERR>2    pre=54    post=54    diff=0
# [LM2005]_NGC_4559_ULX1                  UVOT_U              FLAG_AB_MAG_>1_SIG   pre=54    post=45    diff=9
# [LM2005]_NGC_4559_ULX1                  UVOT_UVM2           FLAG_AB_MAG_99       pre=44    post=44    diff=0
# [LM2005]_NGC_4559_ULX1                  UVOT_UVM2           FLAG_UPPER_LIM       pre=44    post=44    diff=0
# [LM2005]_NGC_4559_ULX1                  UVOT_UVM2           FLAG_AB_MAG_>10_<30  pre=44    post=44    diff=0
# [LM2005]_NGC_4559_ULX1                  UVOT_UVM2           FLAG_AB_MAG_ERR>2    pre=44    post=44    diff=0
# [LM2005]_NGC_4559_ULX1                  UVOT_UVM2           FLAG_AB_MAG_>1_SIG   pre=44    post=37    diff=7
# [LM2005]_NGC_4559_ULX1                  UVOT_UVW1           FLAG_AB_MAG_99       pre=86    post=86    diff=0
# [LM2005]_NGC_4559_ULX1                  UVOT_UVW1           FLAG_UPPER_LIM       pre=86    post=86    diff=0
# [LM2005]_NGC_4559_ULX1                  UVOT_UVW1           FLAG_AB_MAG_>10_<30  pre=86    post=86    diff=0
# [LM2005]_NGC_4559_ULX1                  UVOT_UVW1           FLAG_AB_MAG_ERR>2    pre=86    post=86    diff=0
# [LM2005]_NGC_4559_ULX1                  UVOT_UVW1           FLAG_AB_MAG_>1_SIG   pre=86    post=66    diff=20
# [LM2005]_NGC_4559_ULX1                  UVOT_UVW2           FLAG_AB_MAG_99       pre=95    post=95    diff=0
# [LM2005]_NGC_4559_ULX1                  UVOT_UVW2           FLAG_UPPER_LIM       pre=95    post=95    diff=0
# [LM2005]_NGC_4559_ULX1                  UVOT_UVW2           FLAG_AB_MAG_>10_<30  pre=95    post=95    diff=0
# [LM2005]_NGC_4559_ULX1                  UVOT_UVW2           FLAG_AB_MAG_ERR>2    pre=95    post=95    diff=0
# [LM2005]_NGC_4559_ULX1                  UVOT_UVW2           FLAG_AB_MAG_>1_SIG   pre=95    post=73    diff=22
# [LM2005]_NGC_4559_ULX1                  UVOT_V              FLAG_AB_MAG_99       pre=28    post=28    diff=0
# [LM2005]_NGC_4559_ULX1                  UVOT_V              FLAG_UPPER_LIM       pre=28    post=12    diff=16
# [LM2005]_NGC_4559_ULX1                  UVOT_V              FLAG_AB_MAG_>10_<30  pre=12    post=12    diff=0
# [LM2005]_NGC_4559_ULX1                  UVOT_V              FLAG_AB_MAG_ERR>2    pre=12    post=12    diff=0
# [LM2005]_NGC_4559_ULX1                  UVOT_V              FLAG_AB_MAG_>1_SIG   pre=12    post=8     diff=4

# %%
all_lcs.keys()
# Out:
# dict_keys(['ESO_243-49_HLX-1', 'NAME_Holmberg_IX_X-1', 'Holmberg_II_X-1', 'M31_ULX-1', '[LM2005]_NGC_598_ULX1', 'RX_J133001+47137', '[LM2005]_NGC_3031_ULX1', 'M82_X-2', '[LM2005]_NGC_1042_ULX1', 'NAME_NGC_1313_X-1', 'NAME_NGC_1313_X-2', '[LM2005]_NGC_247_ULX1', '[LB2005]_NGC_253_X20', 'NAME_NGC_300_ULX1', '[LM2005]_NGC_4395_ULX1', '[LM2005]_NGC_5204_ULX1', '[LM2005]_NGC_5408_ULX1', '[SRW2006b]_NGC_55_ULX', '[SST2011]_J141939.39+564137.8', 'NAME_NGC_5907_ULX', '[LB2005]_NGC_6946_ULX1', '3XMM_J213631.9-543357', 'NAME_NGC_7793_P13', 'NAME_NGC_925_ULX-1', 'NAME_NGC_925_ULX-2', 'SMC_X-3', 'SS433', 'SWIFT_J0243.6+6124', 'NAME_UGC_6456_ULX', 'NOVA_Cyg_1989', '[LB2005]_NGC_5236_ULX1', 'NAME_M83_ULX-1', 'NAME_NGC_1365-X1', '[SK2009]_X2', 'NAME_IC_10_X-1', '[WMR2006]_NGC4945_XMM1', '[LB2005]_NGC_3031_X6', '[LM2005]_NGC_4559_ULX1'])

# %%
from astropy.time import Time

# %%
source_gtis = {'NAME_Holmberg_IX_X-1'   : [(54750,55750), (55800,56900),  (59000,59400)],
               'RX_J133001+47137'       : [(58100,59800)],
               '[LM2005]_NGC_3031_ULX1' : [(54750,55750), (55800,57000)],
               'M82_X-2'                : [(56000, 59050)],
               'NAME_NGC_1313_X-1'      : [(56350,59550)],
               'NAME_NGC_1313_X-2'      : [(56350,59550)],
               '[LM2005]_NGC_5408_ULX1' : [(54500,56200)],
               '[LM2005]_NGC_4395_ULX1' : [(54500,55000)],
               'NAME_IC_10_X-1'         : [(58500,59800)],
               'NAME_NGC_7793_P13'      : [(57500,59000)],
               'NAME_NGC_925_ULX-1'     : [(58500,59800)],
               }

# %%
import warnings
from tqdm import tqdm
#warnings.filterwarnings('ignore')

fig, ax = plt.subplots(33, 1, figsize=(20,30), sharex=True)
i=0
for simbad_name, lcs in all_lcs.items():
      
    try:
        tab = lcs['XRT_FULL_PC']
        tab_s = lcs['XRT_SOFT_PC']
        tab_h = lcs['XRT_HARD_PC']
    except:
        continue
    
    try:
        gtis = source_gtis[simbad_name]
        for gti in gtis:
            ax[i].axvspan(gti[0], gti[1], alpha=0.5, color='green')
            
            sub = tab[['MJD', 'RATE', 'RATE_ERR']]
            sub_s = tab_s[['MJD', 'RATE', 'RATE_ERR']]
            sub_h = tab_h[['MJD', 'RATE', 'RATE_ERR']]
            
            sub.write(f'../lightcurves/for_dauser/{simbad_name}_FULL_{gti[0]}_{gti[1]}.csv')
            sub_s.write(f'../lightcurves/for_dauser/{simbad_name}_SOFT_{gti[0]}_{gti[1]}.csv')
            sub_h.write(f'../lightcurves/for_dauser/{simbad_name}_HARD_{gti[0]}_{gti[1]}.csv')
    except:
        pass
            
    

    tab['MJD_0'] = tab['MJD'] - tab['MJD'].min()
    #ax[i].errorbar(tab['MJD_0'], tab['RATE'], yerr=tab['RATE_ERR'], label=simbad_name, ls='none', lw=1.0, capsize=1.0)
    ax[i].errorbar(tab['MJD'], tab['RATE'], yerr=tab['RATE_ERR'], label=simbad_name, ls='none', lw=1.0, capsize=1.0, color='black')
    ax[i].errorbar(tab_s['MJD'], tab_s['RATE'], yerr=tab_s['RATE_ERR'], ls='none', lw=1.0, capsize=1.0, color='blue')
    ax[i].errorbar(tab_h['MJD'], tab_h['RATE'], yerr=tab_h['RATE_ERR'], ls='none', lw=1.0, capsize=1.0, color='red')
    
    ax[i].legend(loc='upper left')
    i+=1
    
plt.subplots_adjust(hspace=0)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Input In [12], in <cell line: 7>()
#      33 tab['MJD_0'] = tab['MJD'] - tab['MJD'].min()
#      34 #ax[i].errorbar(tab['MJD_0'], tab['RATE'], yerr=tab['RATE_ERR'], label=simbad_name, ls='none', lw=1.0, capsize=1.0)
# ---> 35 ax[i].errorbar(tab['MJD'], tab['RATE'], yerr=tab['RATE_ERR'], label=simbad_name, ls='none', lw=1.0, capsize=1.0, color='black')
#      36 ax[i].errorbar(tab_s['MJD'], tab_s['RATE'], yerr=tab_s['RATE_ERR'], ls='none', lw=1.0, capsize=1.0, color='blue')
#      37 ax[i].errorbar(tab_h['MJD'], tab_h['RATE'], yerr=tab_h['RATE_ERR'], ls='none', lw=1.0, capsize=1.0, color='red')
#
# IndexError: index 33 is out of bounds for axis 0 with size 33

# %%
sources_to_plot = ['NAME_NGC_1313_X-1', 'NAME_Holmberg_IX_X-1', 'M82_X-2', 'NAME_NGC_7793_P13']
labels          = ['NGC1313 X-1', 'Holmberg IX X-1', 'M82_X-2', 'NGC7793 P13']

nplot = len(sources_to_plot)
fig, ax = plt.subplots(nplot,1, figsize=(15,3*len(sources_to_plot)))

for i, s in enumerate(sources_to_plot):
    tab = all_lcs[s]['XRT_FULL_PC']
    tab['YEAR'] = Time(tab['MJD'], format='mjd').to_value(format='decimalyear')
    ax[i].errorbar(tab['YEAR'], tab['RATE'], yerr=(np.abs(tab['RATE_ERR_NEG']), tab['RATE_ERR_POS']), ls='none', lw=1.0, capsize=1.0, marker='.', color='black', label=labels[i])
    
for a in ax:
    a.set_ylabel('Count Rate (0.3 - 10.0 keV)')
    a.set_xlabel('Year')
    a.legend(loc='upper left', prop={'size': 15})
ax[0].set_xlim(2013)
ax[1].set_xlim(2008.8,2016)
ax[2].set_xlim(2012,2021)
ax[3].set_xlim(2016,2020)

plt.tight_layout()
plt.savefig('../figures/swift_lcs.png', facecolor='white')

# %%
import warnings
warnings.filterwarnings('ignore')

for simbad_name, lcs in all_lcs.items():
    for xrt_key in ['XRT_FULL_PC', 'XRT_SOFT_PC', 'XRT_HARD_PC', 'XRT_HR_PC']:
        try:
            tab_xrt  = lcs[xrt_key]
        except:
            continue

        for lc_name, tab in lcs.items():
            N_OBS = len(np.unique(tab['OBSID']))
            if 'UVOT' in lc_name:

                tab_uvot = lcs[lc_name]
                if len(tab_uvot) < 30:
                    continue
                tab_uvot = tab_uvot.group_by('OBSID').groups.aggregate(np.mean) # Calculate the mean for duplicated groups
                #tab_uvot  = unique(tab_uvot, keys='OBSID')    # Remove duplicate observation IDS
                tab_join = join(tab_uvot, tab_xrt , join_type='inner', keys='OBSID')
                try:
                    tab_join = tab_join[~tab_join['RATE'].mask]
                except:
                    pass
                
                if len(tab_join) < 10:
                    continue

                from scipy.optimize import curve_fit
                from scipy.stats import pearsonr

                def line(x, m, c):
                    return m*x+c

                p_opt, p_cov = curve_fit(line, tab_join['AB_MAG'], tab_join['RATE'])
                r, p_val = pearsonr(tab_join['AB_MAG'], tab_join['RATE'])

                # Plotting
                fig, ax = plt.subplots(1,2, figsize=(25,5), gridspec_kw={'width_ratios': [4, 1]})

                ax[0].set_title(f'{simbad_name} | {xrt_key} | {lc_name} | {len(tab_join)}')
                ax[0].errorbar(tab_join['MJD'], tab_join['AB_MAG'], yerr=tab_join['AB_MAG_ERR'], ls='none', lw=1.0, capsize=1.0, marker='.', color='darkviolet')

                ax2 = ax[0].twinx()
                ax[0].invert_yaxis()
                ax2.errorbar(tab_join['MJD'], tab_join['RATE'], yerr=tab_join['RATE_ERR'], ls='none', lw=1.0, capsize=1.0, marker='.', color='black')
                ax[0].set_ylabel(f'{lc_name} AB MAG (mag)')
                ax[0].set_xlabel('MJD2000')
                ax2.set_ylabel('XRT RATE (ct/s)')

                ax[1].set_title(f'{simbad_name} | {xrt_key} | {lc_name} | {len(tab_join)} \n m={p_opt[0]:.2e} c={p_opt[1]:.2f} r={r:.2f} p_val={p_val:.2f}')
                ax[1].scatter(tab_join['AB_MAG'], tab_join['RATE'], marker='x', color='black')
                ax[1].set_xlabel('AB_MAG')
                xlow, xhigh = ax[1].get_xlim()
                xrange = np.linspace(xlow, xhigh, 100)
                ax[1].plot(xrange, line(xrange, *p_opt), color='red')
                plt.tight_layout()
                plt.savefig(f'../figures/{simbad_name}_{xrt_key}_{lc_name}_lc_unbinned_corr.png', facecolor='white')

                plt.show()

# %%
import warnings
#warnings.filterwarnings('ignore')

uvot_key = 'CORR_RATE'
uvot_key_err = 'CORR_RATE_ERR'

for simbad_name, lcs in all_lcs.items():
    for xrt_key in ['XRT_FULL_PC', 'XRT_SOFT_PC', 'XRT_HARD_PC', 'XRT_HR_PC']:
        try:
            tab_xrt  = lcs[xrt_key]
        except:
            continue

        for lc_name, tab in lcs.items():
            N_OBS = len(np.unique(tab['OBSID']))
            if 'UVOT' in lc_name:

                tab_uvot = lcs[lc_name]
                if len(tab_uvot) < 30:
                    continue
                tab_uvot = tab_uvot.group_by('OBSID').groups.aggregate(np.mean) # Calculate the mean for duplicated groups
                #tab_uvot  = unique(tab_uvot, keys='OBSID')    # Remove duplicate observation IDS
                tab_join = join(tab_uvot, tab_xrt , join_type='inner', keys='OBSID')
                try:
                    tab_join = tab_join[~tab_join['RATE'].mask]
                except:
                    pass
                
                if len(tab_join) < 30:
                    print(simbad_name, lc_name, len(tab_join))
                    continue
                    

                def line(x, m, c):
                    return m*x+c

                p_opt, p_cov = curve_fit(line, tab_join[uvot_key], tab_join['RATE'])
                r, p_val = pearsonr(tab_join[uvot_key], tab_join['RATE'])

                # Plotting
                fig, ax = plt.subplots(1,2, figsize=(25,5), gridspec_kw={'width_ratios': [4, 1]})

                ax[0].set_title(f'{simbad_name} | {xrt_key} | {lc_name} | {len(tab_join)}')
                ax[0].errorbar(tab_join['MJD'], tab_join[uvot_key], yerr=tab_join[uvot_key_err], ls='none', lw=1.0, capsize=1.0, marker='.', color='darkviolet')

                ax2 = ax[0].twinx()
                # ax[0].invert_yaxis()
                ax2.errorbar(tab_join['MJD'], tab_join['RATE'], yerr=tab_join['RATE_ERR'], ls='none', lw=1.0, capsize=1.0, marker='.', color='black')
                ax[0].set_ylabel(f'{lc_name} {uvot_key} ({tab_uvot[uvot_key].unit})')
                ax[0].set_xlabel('MJD2000')
                ax2.set_ylabel('XRT RATE (ct/s)')

                ax[1].set_title(f'{simbad_name} | {xrt_key} | {lc_name} | {len(tab_join)} \n m={p_opt[0]:.2e} c={p_opt[1]:.2f} r={r:.2f} p_val={p_val:.2f}')
                ax[1].scatter(tab_join[uvot_key], tab_join['RATE'], marker='x', color='black')
                ax[1].set_xlabel(uvot_key)
                xlow, xhigh = ax[1].get_xlim()
                xrange = np.linspace(xlow, xhigh, 100)
                ax[1].plot(xrange, line(xrange, *p_opt), color='red')
                plt.tight_layout()
                #plt.savefig(f'../figures/{simbad_name}_{xrt_key}_{lc_name}_lc_corr.png')

                plt.show()

# %%
tab = join(all_lcs['NAME_NGC_1313_X-1']['XRT_FULL_PC'], all_lcs['NAME_NGC_1313_X-1']['UVOT_U'], keys='OBSID', join_type='inner')
tab

# %%
tab = tab[tab['AB_MAG'] < 18.5]
tab = tab[tab['AB_MAG'] > 17.00]
tab = tab[tab['RATE'] > 0.01]

plt.figure(figsize=(6,6))
plt.scatter(tab['RATE'], tab['AB_MAG'])

# %%
bin_low  = tab['RATE'].min()
bin_high = tab['RATE'].max()
nbins = 10
rate_bins = np.linspace(bin_low, bin_high, nbins)
bin_step = (bin_high - bin_low) / nbins
rate_bins

# %%
all_rows = []
for bin_low in rate_bins:
    row = {}
    bin_high = bin_low + bin_step
    sub = tab[(tab['RATE'] > bin_low) & (tab['RATE'] < bin_high)]
    n = len(sub)
    rate_mean = np.mean(sub['RATE'])
    rate_sigma = np.std(sub['RATE'])
    rate_se  =  rate_sigma / n
    
    mag_mean = np.mean(sub['AB_MAG'])
    mag_sigma = np.std(sub['AB_MAG'])
    mag_se = mag_sigma / n
    #print(f'{bin_low:<.2f} {bin_high:<.2f} {bin_step:<5} {n:<5} {rate_mean:.4f} {rate_sigma:.4f} {rate_se:.4f}')
    
    row['rate_bin_low'] = bin_low
    row['rate_bin_high'] = bin_high
    row['rate_bin_step'] = bin_step
    row['rate_n_bins'] = nbins
    row['rate_bin_step'] = bin_step
    
    
    row['n'] = n
    row['rate_mean'] = rate_mean
    row['rate_sigma'] = rate_sigma
    row['rate_se'] = rate_se
    row['mag_mean'] = mag_mean
    row['mag_sigma'] = mag_sigma
    row['mag_se'] = mag_se
    all_rows.append(row)
    

df = pd.DataFrame(all_rows)
print(df)

plt.figure(figsize=(6,6))
plt.errorbar(df['rate_mean'], df['mag_mean'], xerr=df['rate_sigma'], yerr=df['mag_sigma'], ls='none', lw=1.0, capsize=1.0)
plt.figure(figsize=(6,6))
plt.errorbar(df['rate_mean'], df['mag_mean'], xerr=df['rate_se'], yerr=df['mag_se'], ls='none', lw=1.0, capsize=1.0)

# %%
import warnings
#warnings.filterwarnings('ignore')

uvot_key = 'CORR_RATE'
uvot_key_err = 'CORR_RATE_ERR'

for simbad_name, lcs in all_lcs.items():
    for xrt_key in ['XRT_FULL_PC', 'XRT_SOFT_PC', 'XRT_HARD_PC', 'XRT_HR_PC']:
        row = {}
        try:
            tab_xrt  = lcs[xrt_key]
        except:
            continue

        for lc_name, tab in lcs.items():
            N_OBS = len(np.unique(tab['OBSID']))
            if 'UVOT' in lc_name:

                tab_uvot = lcs[lc_name]
                if len(tab_uvot) < 30:
                    continue
                tab_uvot = tab_uvot.group_by('OBSID').groups.aggregate(np.mean) # Calculate the mean for duplicated groups
                #tab_uvot  = unique(tab_uvot, keys='OBSID')    # Remove duplicate observation IDS
                tab_join = join(tab_uvot, tab_xrt , join_type='inner', keys='OBSID')
                try:
                    tab_join = tab_join[~tab_join['RATE'].mask]
                except:
                    pass
                
                if len(tab_join) < 30:
                    continue

                def line(x, m, c):
                    return m*x+c

                bin_low  = tab_join['RATE'].min()
                bin_high = tab_join['RATE'].max()
                nbins = 10
                rate_bins = np.linspace(bin_low, bin_high, nbins)
                bin_step = (bin_high - bin_low) / nbins
                
                all_rows = []
                
                for bin_low in rate_bins:
                    row = {}
                    bin_high = bin_low + bin_step
                    sub = tab_join[(tab_join['RATE'] > bin_low) & (tab_join['RATE'] < bin_high)]
                    n = len(sub)
                    rate_mean = np.mean(sub['RATE'])
                    rate_sigma = np.std(sub['RATE'])
                    rate_se  =  rate_sigma / np.sqrt(n)

                    mag_mean = np.mean(sub['AB_MAG'])
                    mag_sigma = np.std(sub['AB_MAG'])
                    mag_se = mag_sigma / np.sqrt(n)
                    
                    row['rate_bin_low'] = bin_low
                    row['rate_bin_high'] = bin_high
                    row['rate_bin_step'] = bin_step
                    row['rate_n_bins'] = nbins
                    row['rate_bin_step'] = bin_step

                    row['n'] = n
                    row['rate_mean'] = rate_mean
                    row['rate_sigma'] = rate_sigma
                    row['rate_se'] = rate_se
                    row['mag_mean'] = mag_mean
                    row['mag_sigma'] = mag_sigma
                    row['mag_se'] = mag_se
                    all_rows.append(row)
                
                df = pd.DataFrame(all_rows)
                df_fit = df[df['n'] != 0]
                #print(df)
                if len(df_fit) > 1:
                    p_opt1, p_cov1 = curve_fit(line, df_fit['rate_mean'], df_fit['mag_mean'], sigma=df_fit['mag_sigma'])
                    p_opt2, p_cov2 = curve_fit(line, df_fit['rate_mean'], df_fit['mag_mean'], sigma=df_fit['mag_se'])

                    r, p_val = pearsonr(df_fit['rate_mean'], df_fit['mag_mean'])
                else:
                    p_opt1[0] = 1.00
                    

                fig, ax = plt.subplots(1,2, figsize=(12,6))

                ax[0].set_title(f'{simbad_name} | {xrt_key} | {lc_name} | {len(tab_join)} | $\sigma$ \n r={r:.3f} p_val={p_val:.3f}')
                ax[1].set_title(f'{simbad_name} | {xrt_key} | {lc_name} | {len(tab_join)} | $SE$ \n r={r:.3f} p_val={p_val:.3f}')
                ax[0].set_xlabel('XRT RATE')
                ax[0].set_ylabel('AB MAG')
                
                ax[0].scatter(tab_join['RATE'], tab_join['AB_MAG'], marker='x', color='grey', alpha=0.8)
                ax[1].scatter(tab_join['RATE'], tab_join['AB_MAG'], marker='x', color='grey', alpha=0.8)
                
                ax[0].errorbar(df['rate_mean'], df['mag_mean'], xerr=df['rate_sigma'], yerr=df['mag_sigma'], ls='none', lw=1.0, capsize=1.0, color='black')
                ax[1].errorbar(df['rate_mean'], df['mag_mean'], xerr=df['rate_se'], yerr=df['mag_se'], ls='none', lw=1.0, capsize=1.0, color='black')
                
                xlow, xhigh = ax[0].get_xlim()
                xrange = np.linspace(xlow, xhigh, 100)
                if p_opt1[0]!=1.00:
                    ax[0].plot(xrange, line(xrange, p_opt1[0], p_opt1[1]), color='red', label=f'y={p_opt1[0]:.2f}x+{p_opt1[1]:.2f}')
                    ax[1].plot(xrange, line(xrange, p_opt2[0], p_opt2[1]), color='red', label=f'y={p_opt2[0]:.2f}x+{p_opt2[1]:.2f}')
                    ax[0].legend()
                    ax[1].legend()
                
                ax[0].set_xlim(xlow, xhigh)
                ax[1].set_xlim(xlow, xhigh)
                
                
                #ax[0].invert_yaxis()
                #ax[1].invert_yaxis()
                plt.savefig(f'../figures/{simbad_name}_{xrt_key}_{lc_name}_corr_binned.png', facecolor='white')
                plt.show()

# %%
from astropy.units import day
from statsmodels.tsa.stattools import ccf

# %%
plt.plot(all_lcs['NAME_Holmberg_IX_X-1']['XRT_FULL_PC']['MJD'] , all_lcs['NAME_Holmberg_IX_X-1']['XRT_FULL_PC']['RATE'])

# %%
gtis = [(56000,56800),
        (59000,62000),
        ]

for gti in gtis:
    tab_xrt = all_lcs['NAME_Holmberg_IX_X-1']['XRT_FULL_PC']
    tab_uvot  = all_lcs['NAME_Holmberg_IX_X-1']['UVOT_UVW2']
    
    tab_join = join(tab_uvot, tab_xrt , join_type='inner', keys='OBSID')
    
    sub = tab_join[(tab_join['MJD'] > gti[0]) & (tab_join['MJD'] < gti[1])]
    
    
    fig = plt.figure(figsize=(25,10), constrained_layout=False)
    gs1 = fig.add_gridspec(nrows=4, ncols=4, left=0.07, right=0.48, wspace=0.05)
    ax1 = fig.add_subplot(gs1[:2, :4])
    ax2 = fig.add_subplot(gs1[-2, :-1])
    ax3 = fig.add_subplot(gs1[-2, -1])
    ax4 = fig.add_subplot(gs1[3,3])
    ax5 = fig.add_subplot(gs1[3:,2:3])

    ax1.errorbar(sub['MJD'], sub['RATE'], yerr=(np.abs(sub['RATE_ERR_NEG']), sub['RATE_ERR_POS']), marker='.', ls='none', lw=1.0, capsize=1.0, color='black')
    ax1_t = ax1.twinx()
    ax1_t.errorbar(sub['MJD'], sub['MAG'], yerr=sub['MAG_ERR'], marker='.', ls='none', lw=1.0, capsize=1.0, color='darkviolet')

    freq_uv, power_uv = LombScargle(sub['MJD'], sub['MAG']).autopower(minimum_frequency=0.07)
    freq_xrt, power_xrt = LombScargle(sub['MJD'], sub['RATE']).autopower(minimum_frequency=0.07)
    f_max_uv = freq_uv[power_uv.argmax()]
    f_max_xrt = freq_xrt[power_xrt.argmax()]
    
    ax2.plot(freq_uv, power_uv, lw=1.0, color='darkviolet')
    ax2.axvline(f_max_uv, color='red', ls='--', lw=2.0)
    ax2_1 = ax2.twinx()
    ax2_1.plot(freq_xrt, power_xrt, lw=1.0, color='black')
    ax2_1.axvline(f_max_xrt, color='grey', ls='--', lw=2.0)
    
    
    ax3.plot(ccf(sub['RATE'], sub['MAG']))
    ax3.plot(ccf(sub['MAG'], sub['RATE']))
    
    ax4.hist(sub['MAG'], histtype='step', color='darkviolet', bins=20)
    ax4_1 = ax4.twiny()
    ax4_1.hist(sub['RATE'], histtype='step', color='black', bins=20)
    
    ax5.scatter(sub['RATE'], sub['MAG'], c=range(len(sub)), s=4.0, marker='s')
    #ax5.loglog()

# %%
gtis = 

for gti in gtis:
    tab_xrt   = all_lcs[]['XRT_FULL_PC']
    tab_uvot  = all_lcs['NAME_NGC_1313_X-1']['UVOT_UVW2']
    
    tab_join = join(tab_uvot, tab_xrt , join_type='inner', keys='OBSID')
    
    sub = tab_join[(tab_join['MJD'] > gti[0]) & (tab_join['MJD'] < gti[1])]
    
    
    fig = plt.figure(figsize=(25,10), constrained_layout=False)
    gs1 = fig.add_gridspec(nrows=4, ncols=4, left=0.07, right=0.48, wspace=0.05)
    ax1 = fig.add_subplot(gs1[:2, :4])
    ax2 = fig.add_subplot(gs1[-2, :-1])
    ax3 = fig.add_subplot(gs1[-2, -1])
    ax4 = fig.add_subplot(gs1[3,3])
    ax5 = fig.add_subplot(gs1[3:,2:3])

    ax1.errorbar(sub['MJD'], sub['RATE'], yerr=(np.abs(sub['RATE_ERR_NEG']), sub['RATE_ERR_POS']), marker='.', ls='none', lw=1.0, capsize=1.0, color='black')
    ax1_t = ax1.twinx()
    ax1_t.errorbar(sub['MJD'], sub['MAG'], yerr=sub['MAG_ERR'], marker='.', ls='none', lw=1.0, capsize=1.0, color='darkviolet')

    freq_uv, power_uv = LombScargle(sub['MJD'], sub['MAG']).autopower(minimum_frequency=0.07)
    freq_xrt, power_xrt = LombScargle(sub['MJD'], sub['RATE']).autopower(minimum_frequency=0.07)
    f_max_uv = freq_uv[power_uv.argmax()]
    f_max_xrt = freq_xrt[power_xrt.argmax()]
    
    ax2.plot(freq_uv, power_uv, lw=1.0, color='darkviolet')
    ax2.axvline(f_max_uv, color='red', ls='--', lw=2.0)
    ax2_1 = ax2.twinx()
    ax2_1.plot(freq_xrt, power_xrt, lw=1.0, color='black')
    ax2_1.axvline(f_max_xrt, color='grey', ls='--', lw=2.0)
    
    
    ax3.plot(ccf(sub['RATE'], sub['MAG']))
    ax3.plot(ccf(sub['MAG'], sub['RATE']))
    
    ax4.hist(sub['MAG'], histtype='step', color='darkviolet', bins=20)
    ax4_1 = ax4.twiny()
    ax4_1.hist(sub['RATE'], histtype='step', color='black', bins=20)
    
    ax5.scatter(sub['RATE'], sub['MAG'], c=range(len(sub)), s=4.0, marker='s')
    ax5.loglog()

# %%
for gti in gtis:
    tab_xrt   = all_lcs['[LM2005]_NGC_5408_ULX1']['XRT_FULL_PC']
    tab_uvot  = all_lcs['[LM2005]_NGC_5408_ULX1']['UVOT_UVM2']
    
    tab_join = join(tab_uvot, tab_xrt , join_type='inner', keys='OBSID')
    
    sub = tab_join[(tab_join['MJD'] > gti[0]) & (tab_join['MJD'] < gti[1])]
    
    
    fig = plt.figure(figsize=(25,10), constrained_layout=False)
    gs1 = fig.add_gridspec(nrows=4, ncols=4, left=0.07, right=0.48, wspace=0.05)
    ax1 = fig.add_subplot(gs1[:2, :4])
    ax2 = fig.add_subplot(gs1[-2, :-1])
    ax3 = fig.add_subplot(gs1[-2, -1])
    ax4 = fig.add_subplot(gs1[3,3])
    ax5 = fig.add_subplot(gs1[3:,2:3])

    ax1.errorbar(sub['MJD'], sub['RATE'], yerr=(np.abs(sub['RATE_ERR_NEG']), sub['RATE_ERR_POS']), marker='.', ls='none', lw=1.0, capsize=1.0, color='black')
    ax1_t = ax1.twinx()
    ax1_t.errorbar(sub['MJD'], sub['MAG'], yerr=sub['MAG_ERR'], marker='.', ls='none', lw=1.0, capsize=1.0, color='darkviolet')

    freq_uv, power_uv = LombScargle(sub['MJD'], sub['MAG']).autopower(minimum_frequency=0.07)
    freq_xrt, power_xrt = LombScargle(sub['MJD'], sub['RATE']).autopower(minimum_frequency=0.07)
    f_max_uv = freq_uv[power_uv.argmax()]
    f_max_xrt = freq_xrt[power_xrt.argmax()]
    
    ax2.plot(freq_uv, power_uv, lw=1.0, color='darkviolet')
    ax2.axvline(f_max_uv, color='red', ls='--', lw=2.0)
    ax2_1 = ax2.twinx()
    ax2_1.plot(freq_xrt, power_xrt, lw=1.0, color='black')
    ax2_1.axvline(f_max_xrt, color='grey', ls='--', lw=2.0)
    
    
    ax3.plot(ccf(sub['RATE'], sub['MAG']))
    ax3.plot(ccf(sub['MAG'], sub['RATE']))
    
    ax4.hist(sub['MAG'], histtype='step', color='darkviolet', bins=20)
    ax4_1 = ax4.twiny()
    ax4_1.hist(sub['RATE'], histtype='step', color='black', bins=20)
    
    ax5.scatter(sub['RATE'], sub['MAG'], c=range(len(sub)), s=4.0, marker='s')
    ax5.loglog()

# %%
    


gtis = 

for gti in gtis:
    tab_xrt   = all_lcs[]['XRT_FULL_PC']
    tab_uvot  = all_lcs['[LM2005]_NGC_4395_ULX1']['UVOT_B']
    
    tab_join = join(tab_uvot, tab_xrt , join_type='inner', keys='OBSID')
    
    sub = tab_join[(tab_join['MJD'] > gti[0]) & (tab_join['MJD'] < gti[1])]
    
    
    fig = plt.figure(figsize=(25,10), constrained_layout=False)
    gs1 = fig.add_gridspec(nrows=4, ncols=4, left=0.07, right=0.48, wspace=0.05)
    ax1 = fig.add_subplot(gs1[:2, :4])
    ax2 = fig.add_subplot(gs1[-2, :-1])
    ax3 = fig.add_subplot(gs1[-2, -1])
    ax4 = fig.add_subplot(gs1[3,3])
    ax5 = fig.add_subplot(gs1[3:,2:3])

    ax1.errorbar(sub['MJD'], sub['RATE'], yerr=(np.abs(sub['RATE_ERR_NEG']), sub['RATE_ERR_POS']), marker='.', ls='none', lw=1.0, capsize=1.0, color='black')
    ax1_t = ax1.twinx()
    ax1_t.errorbar(sub['MJD'], sub['MAG'], yerr=sub['MAG_ERR'], marker='.', ls='none', lw=1.0, capsize=1.0, color='darkviolet')

    freq_uv, power_uv = LombScargle(sub['MJD'], sub['MAG']).autopower(minimum_frequency=0.07)
    freq_xrt, power_xrt = LombScargle(sub['MJD'], sub['RATE']).autopower(minimum_frequency=0.07)
    f_max_uv = freq_uv[power_uv.argmax()]
    f_max_xrt = freq_xrt[power_xrt.argmax()]
    
    ax2.plot(freq_uv, power_uv, lw=1.0, color='darkviolet')
    
    ax2_1 = ax2.twinx()
    ax2_1.plot(freq_xrt, power_xrt, lw=1.0, color='black')
    
    ax2.axvline(f_max_uv, color='red', ls='--', lw=2.0, label=f'UV = {f_max_uv:.3f} days^-1')
    ax2_1.axvline(f_max_xrt, color='grey', ls='--', lw=2.0, label=f'XRT {f_max_xrt:.3f} days^-1')
    ax2.legend()
    ax2_1.legend()
    
    
    ax3.plot(ccf(sub['RATE'], sub['MAG']))
    ax3.plot(ccf(sub['MAG'], sub['RATE']))
    
    ax4.hist(sub['MAG'], histtype='step', color='darkviolet', bins=20)
    ax4_1 = ax4.twiny()
    ax4_1.hist(sub['RATE'], histtype='step', color='black', bins=20)
    
    ax5.scatter(sub['RATE'], sub['MAG'], c=range(len(sub)), s=4.0, marker='s')
    ax5.loglog()

# %%
gtis = 

for gti in gtis:
    tab_xrt   = all_lcs['NAME_IC_10_X-1']['XRT_FULL_PC']
    tab_uvot  = all_lcs['NAME_IC_10_X-1']['UVOT_U']
    
    tab_join = join(tab_uvot, tab_xrt , join_type='inner', keys='OBSID')
    
    sub = tab_join[(tab_join['MJD'] > gti[0]) & (tab_join['MJD'] < gti[1])]
    
    
    fig = plt.figure(figsize=(25,10), constrained_layout=False)
    gs1 = fig.add_gridspec(nrows=4, ncols=4, left=0.07, right=0.48, wspace=0.05)
    ax1 = fig.add_subplot(gs1[:2, :4])
    ax2 = fig.add_subplot(gs1[-2, :-1])
    ax3 = fig.add_subplot(gs1[-2, -1])
    ax4 = fig.add_subplot(gs1[3,3])
    ax5 = fig.add_subplot(gs1[3:,2:3])

    ax1.errorbar(sub['MJD'], sub['RATE'], yerr=(np.abs(sub['RATE_ERR_NEG']), sub['RATE_ERR_POS']), marker='.', ls='none', lw=1.0, capsize=1.0, color='black')
    ax1_t = ax1.twinx()
    ax1_t.errorbar(sub['MJD'], sub['MAG'], yerr=sub['MAG_ERR'], marker='.', ls='none', lw=1.0, capsize=1.0, color='darkviolet')

    ls_uv  = LombScargle(sub['MJD'], sub['MAG'], sub['MAG_ERR'])
    ls_xrt = LombScargle(sub['MJD'], sub['RATE'], sub['RATE_ERR'])
    
    freq_uv, power_uv = ls_uv.autopower(minimum_frequency=0.07)
    freq_xrt, power_xrt = ls_xrt.autopower(minimum_frequency=0.07)
    
    f_max_uv = freq_uv[power_uv.argmax()]
    f_max_xrt = freq_xrt[power_xrt.argmax()]
    
    ax2.plot(freq_uv, power_uv, lw=1.0, color='darkviolet')
    
    ax2_1 = ax2.twinx()
    ax2_1.plot(freq_xrt, power_xrt, lw=1.0, color='black')
    ax2.axvline(f_max_uv, color='red', ls='--', lw=2.0, label=f'UV = {f_max_uv:.3f}  days^-1')
    ax2_1.axvline(f_max_xrt, color='grey', ls='--', lw=2.0, label=f'XRT {f_max_xrt:.3f}  days^-1')
    ax2.legend()
    ax2_1.legend()
    
    
    ax3.plot(ccf(sub['RATE'], sub['MAG']))
    ax3.plot(ccf(sub['MAG'], sub['RATE']))
    
    ax4.hist(sub['MAG'], histtype='step', color='darkviolet', bins=20)
    ax4_1 = ax4.twiny()
    ax4_1.hist(sub['RATE'], histtype='step', color='black', bins=20)
    
    ax5.scatter(sub['RATE'], sub['MAG'], c=range(len(sub)), s=4.0, marker='s')
    ax5.loglog()

# %%
for key, lcs in all_lcs.items():
    for lc_key, lc in lcs.items():
        fn = f'{key}_{lc_key}.csv'
        
        if len(lc) > 50:
            if 'XRT' in lc_key:
                sub = lc[['MJD', 'RATE', 'RATE_ERR']]
            elif 'UVOT' in lc_key:
                lc['MJD'] = 51910 + lc['MET'] / 86400.0
                sub = lc[['MJD', 'MAG', 'MAG_ERR']]
                sub.rename_column('MAG', 'RATE')
                sub.rename_column('MAG_ERR', 'RATE_ERR')
            sub.write(f'../lightcurves/{fn}', format='csv')
                
            print(fn)
            print(len(lc))

# %%
x,y = LombScargle(sub['MJD'], sub['RATE']).autopower(minimum_frequency=0.05) 
plt.plot(x,y)

# %%
fig8 = plt.figure(figsize=(15,5), constrained_layout=False)
gs1 = fig8.add_gridspec(nrows=3, ncols=3, left=0.05, right=0.48, wspace=0.05)
f8_ax1 = fig8.add_subplot(gs1[:-1, :])
f8_ax2 = fig8.add_subplot(gs1[-1, :-1])
f8_ax3 = fig8.add_subplot(gs1[-1, -1])

# %%
# ?LombScargle.autofrequency

# %%
# ?LombScargle.autopower
