# %%
import sys
from glob import glob
sys.path.append('../')

# %%
import matplotlib
matplotlib.rcParams['mathtext.fontset'] = 'stix'
matplotlib.rcParams['font.family'] = 'STIXGeneral'

# %%
from source_names_dict import source_names_dict, source_names_w_counterparts, source_names_readable
from get_closest_srcreg import get_src_region_dict
from uvot import load_uvotsource, read_uvotsource, calc_uvot_flags, filters, filter_colors, filter_markers
from xrt import load_xrt, rename_xrt_cols, curves
from lightcurve import LightCurve

# %%
src_region_dict = get_src_region_dict()
# Out:
# Getting source region dict

# %%
name = 'NAME_Holmberg_IX_X-1'
tab_pc = load_xrt(simbad_name=name, curve='PC', pandas=False)
tab_hard = load_xrt(simbad_name=name, curve='HARD', pandas=False)
tab_soft = load_xrt(simbad_name=name, curve='SOFT', pandas=False)
tab_hr = load_xrt(simbad_name=name, curve='HR', pandas=False)
tab_uvot = load_uvotsource(name, src_region_dict, filter_flags=True)
# Out:
# Loading XRT...
# simbad_name=NAME_Holmberg_IX_X-1 curve=PC pandas=False
# Loading file: /mnt/d/anticorr_data/UKSSDC/NAME_Holmberg_IX_X-1/USERPROD_45574/lc/curve_PC.csv
# df shape=(693, 7) unique_obs=693
# XRT FLAG SUMMARY
# ...
# FLAG_RATE=0 = 4 / 693 (0.58%)
# ...
# Loading XRT...
# simbad_name=NAME_Holmberg_IX_X-1 curve=HARD pandas=False
# Loading file: /mnt/d/anticorr_data/UKSSDC/NAME_Holmberg_IX_X-1/USERPROD_45574/lc/hardrat_HARD_PC.csv
# df shape=(686, 6) unique_obs=686
# XRT FLAG SUMMARY
# ...
# FLAG_RATE=0 = 3 / 686 (0.44%)
# ...
# Loading XRT...
# simbad_name=NAME_Holmberg_IX_X-1 curve=SOFT pandas=False
# Loading file: /mnt/d/anticorr_data/UKSSDC/NAME_Holmberg_IX_X-1/USERPROD_45574/lc/hardrat_SOFT_PC.csv
# df shape=(686, 6) unique_obs=686
# XRT FLAG SUMMARY
# ...
# FLAG_RATE=0 = 3 / 686 (0.44%)
# ...
# Loading XRT...
# simbad_name=NAME_Holmberg_IX_X-1 curve=HR pandas=False
# Loading file: /mnt/d/anticorr_data/UKSSDC/NAME_Holmberg_IX_X-1/USERPROD_45574/lc/hardrat_HR_PC.csv
# df shape=(686, 6) unique_obs=686
# ...

# %%
tab_uvot
# Out:
# <Table length=22>
#       MET       EXTNAME      TSTART          TSTOP      ... FLAG_UPPER_LIM FLAG_AB_MAG_ERR>2 FLAG_AB_MAG_>10_<30
#        s                       s               s        ...
#     float64     bytes12     float64         float64     ...      bool             bool               bool
# --------------- ------- --------------- --------------- ... -------------- ----------------- -------------------
# 285944451.32132    UVW2 285944079.93668 285944822.70596 ...          False             False               False
# 285945185.35804    UVW1   285944829.756 285945540.96008 ...          False             False               False
#  286204662.9122    UVW2 286204321.52052 286205004.30388 ...          False             False               False
# 286205326.97821    UVW1 286205012.96472  286205640.9917 ...          False             False               False
# 288013376.31702    UVW2  288013094.4259 288013658.20814 ...          False             False               False
# ...
